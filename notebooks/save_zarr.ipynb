# %%
# %load_ext autoreload
# %autoreload 2

# %%
import xarray as xr
import gfdl_utils as gu
from dask.diagnostics import ProgressBar
import os
import datetime

# %% [markdown]
# ## Save zarr stores
# Chug certain variables into a zarr store in `/work` for later use.
#
# Notebook is separated into four sections that should be considered quasi-independent:
# **SEARCH**
#   - Various functions to find specific files or variables
#   - Most are dependent only on the pp directory
# **SPECIFY**
#   - Give specifics of file(s) to be loaded and saved
#       - `ppname` (subfolder of `pp`)
#       - `out` (averaging of output: `av` or `ts`)
#       - `time` (timespan to be used, usually `*` for all time)
#       - `add` (name of variable (when `out==ts`) or `*` for `out==av`)
#           - `add` can be a list of severable variables, so long as they are all present in `ppname`
#   - Define filename for zarr store and check if it exists
#       - filename : ppname.out.zarr
# **DMGET**
#   - Retrieve specified file(s) from tape
# **LOAD AND SAVE**
#   - Load files into `ds` (loop through variables if several specified in `add`)
#   - Save to zarr store, appending to store if it already exists

# %%
config_id = 'ESM4_1pctCO2_D1'
pp = '/archive/oar.gfdl.cmip6/ESM4/DECK/'+config_id+'/gfdl.ncrc4-intel16-prod-openmp/pp/'
# pp = '/archive/oar.gfdl.cmip6/CM4/warsaw_201710_om4_v1.0.1/'+config_id+'/gfdl.ncrc4-intel16-prod-openmp/pp/'
# pp = '/archive/oar.gfdl.cmip6/ESM4/DECK/'+config_id+'/gfdl.ncrc4-intel16-prod-openmp/pp'
# pp = '/archive/Raphael.Dussin/FMS2019.01.03_devgfdl_20210706/CM4_piControl_c192_OM4p125_v7/gfdl.ncrc4-intel18-prod-openmp/pp'

outdir = '/work/gam/zarr/'+config_id+'/'

# %% [markdown]
# ### SEARCH

# %% [markdown]
# #### List pp names

# %%
gu.core.get_ppnames(pp)
# Out:
# ['.dec',
#  '.checkpoint',
#  'ocean_daily_cmip',
#  'ocean_daily_gfdl',
#  'ocean_daily_1x1deg',
#  'ocean_monthly',
#  'ocean_monthly_1x1deg',
#  'ocean_month_rho2',
#  'ocean_month_rho2_1x1deg',
#  'ocean_monthly_z',
#  'ocean_monthly_z_1x1deg',
#  'ocean_annual',
#  'ocean_annual_1x1deg',
#  'ocean_annual_rho2',
#  'ocean_annual_rho2_1x1deg',
#  'ocean_annual_z',
#  'ocean_annual_z_1x1deg',
#  'ocean_scalar_monthly',
#  'ocean_scalar_annual',
#  'ocean_Barents_opening',
#  'ocean_Bering_Strait',
#  'ocean_Davis_Strait',
#  'ocean_Windward_Passage',
#  'ocean_Denmark_Strait',
#  'ocean_Drake_Passage',
#  'ocean_English_Channel',
#  'ocean_Faroe_Scotland',
#  'ocean_Florida_Bahamas',
#  'ocean_Fram_Strait',
#  'ocean_Iceland_Faroe_V',
#  'ocean_Iceland_Faroe_U',
#  'ocean_Indonesian_Throughflow',
#  'ocean_Mozambique_Channel',
#  'ocean_Pacific_undercurrent',
#  'ocean_Taiwan_Luzon',
#  'ocean_Agulhas_section',
#  'ocean_Gibraltar_Strait',
#  'ocean_Iceland_Norway',
#  'ocean_month_refined',
#  'ocean_month_z_refined',
#  'ocean_month_rho2_refined',
#  'atmos_cmip',
#  'atmos',
#  'atmos_level_cmip',
#  'atmos_level',
#  'atmos_plev39_cmip',
#  'atmos_plev39_6hr',
#  'atmos_plev39_cmip_daily',
#  'atmos_month_aer',
#  'atmos_diurnal_cmip',
#  'atmos_diurnal',
#  'atmos_scalar',
#  'tracer_level',
#  'aerosol_cmip',
#  'land',
#  'land_cubic',
#  'land_instant_cubic',
#  'land_cmip',
#  'land_dust',
#  'river',
#  'river_cubic',
#  'river_instant_cubic',
#  'LUmip_month_psl',
#  'LUmip_month_crp',
#  'LUmip_month_pst',
#  'LUmip_year_psl',
#  'LUmip_year_crp',
#  'LUmip_year_pst',
#  'land_by_species',
#  'fire',
#  'atmos_co2_level',
#  'ocean_cobalt_sfc',
#  'ocean_cobalt_btm',
#  'ocean_cobalt_fdet_100',
#  'ocean_cobalt_tracers_int',
#  'ocean_cobalt_fluxes_int',
#  'ocean_cobalt_tracers_year_z',
#  'ocean_cobalt_omip_daily',
#  'ocean_cobalt_omip_sfc',
#  'ocean_cobalt_omip_2d',
#  'ocean_cobalt_omip_tracers_month_z',
#  'ocean_cobalt_omip_tracers_year_z',
#  'ocean_cobalt_omip_rates_year_z',
#  'ocean_cobalt_omip_daily_1x1deg',
#  'ocean_cobalt_omip_sfc_1x1deg',
#  'ocean_cobalt_omip_2d_1x1deg',
#  'ocean_cobalt_omip_tracers_month_z_1x1deg',
#  'ocean_cobalt_omip_tracers_year_z_1x1deg',
#  'ocean_cobalt_omip_rates_year_z_1x1deg',
#  'atmos_cmip_Plev8',
#  '_delete',
#  'ice',
#  'ice_1x1deg',
#  'LUmip_refined',
#  'LUmip_refined_year',
#  'DO_NOT_USE']

# %% [markdown]
# #### List all available variables

# %%
gu.core.get_allvars(pp)
# Out:
# {'ocean_daily_cmip': ['sos', 'tos', 'zos'],
#  'ocean_daily_gfdl': ['omldamax', 'sossq', 'ssu', 'ssv', 'tossq'],
#  'ocean_daily_1x1deg': ['omldamax', 'sos', 'sossq', 'tos', 'tossq', 'zos'],
#  'ocean_monthly': ['S_diffx_2d',
#   'S_diffy_2d',
#   'sfdsi',
#   'sob',
#   'sos',
#   'sossq',
#   'T_adx_2d',
#   'T_ady_2d',
#   'tauuo',
#   'tauvo',
#   'T_diffx_2d',
#   'T_diffy_2d',
#   'temp_layer_ave',
#   'tob',
#   'tos',
#   'tossq',
#   'udml_restrat',
#   'uml_restrat',
#   'umo_2d',
#   'ustar',
#   'vdml_restrat',
#   'vml_restrat',
#   'vmo_2d',
#   'wfo',
#   'zos',
#   'zossq',
#   'friver',
#   'heat_content_cond',
#   'heat_content_fprec',
#   'heat_content_massin',
#   'heat_content_massout',
#   'evs',
#   'ficeberg',
#   'heat_content_surfwater',
#   'heat_content_vprec',
#   'Heat_PmE',
#   'hfevapds_old',
#   'hfevapds',
#   'mlotstmax',
#   'mlotstmin',
#   'mlotst',
#   'mlotstsq',
#   'MSTAR',
#   'net_heat_coupler',
#   'net_massin',
#   'net_massout',
#   'nonpenSW',
#   'pbo',
#   'prlq',
#   'prsn',
#   'pso',
#   'rlntds',
#   'rsdo',
#   'rsntds',
#   'S_adx_2d',
#   'S_ady_2d',
#   'salt_layer_ave',
#   'hfds',
#   'hfibthermds',
#   'hflso',
#   'hfrainds',
#   'hfrunoffds',
#   'hfsifrazil',
#   'hfsnthermds',
#   'hfsso',
#   'LwLatSens',
#   'MLD_003',
#   'MLD_restrat'],
#  'ocean_monthly_1x1deg': ['rlntds',
#   'rsntds',
#   'hfrainds',
#   'hfrunoffds',
#   'hfsifrazil',
#   'hfsnthermds',
#   'hfsso',
#   'LwLatSens',
#   'MLD_003',
#   'MLD_restrat',
#   'mlotstmax',
#   'mlotstmin',
#   'mlotst',
#   'mlotstsq',
#   'MSTAR',
#   'net_heat_coupler',
#   'net_massin',
#   'net_massout',
#   'nonpenSW',
#   'pbo',
#   'prlq',
#   'prsn',
#   'pso',
#   'sfdsi',
#   'sob',
#   'sos',
#   'sossq',
#   'tob',
#   'tos',
#   'tossq',
#   'ustar',
#   'wfo',
#   'zos',
#   'zossq',
#   'evs',
#   'ficeberg',
#   'friver',
#   'heat_content_cond',
#   'heat_content_fprec',
#   'heat_content_massin',
#   'heat_content_massout',
#   'heat_content_surfwater',
#   'heat_content_vprec',
#   'Heat_PmE',
#   'hfds',
#   'hfibthermds',
#   'hflso',
#   'hfevapds_old',
#   'hfevapds'],
#  'ocean_month_rho2': ['vhGM', 'vhml', 'vmo', 'volcello', 'vo', 'thkcello'],
#  'ocean_month_rho2_1x1deg': ['thkcello', 'volcello'],
#  'ocean_monthly_z': ['obvfsq',
#   'so',
#   'thetao',
#   'uhGM',
#   'uhml',
#   'umo',
#   'uo',
#   'vhGM',
#   'vhml',
#   'vmo',
#   'volcello',
#   'vo',
#   'zostoga'],
#  'ocean_monthly_z_1x1deg': ['obvfsq', 'so', 'thetao', 'volcello'],
#  'ocean_annual': ['masscello',
#   'mass_wt',
#   'boundary_forcing_heat_tendency_2d',
#   'boundary_forcing_salt_tendency_2d',
#   'diabatic_diff_saln_tendency',
#   'diabatic_diff_temp_tendency',
#   'diftrelo',
#   'dispkexyfo',
#   'e',
#   'evs',
#   'ficeberg',
#   'frazil_heat_tendency_2d',
#   'friver',
#   'heat_content_cond',
#   'heat_content_fprec',
#   'heat_content_massin',
#   'heat_content_massout',
#   'heat_content_surfwater',
#   'heat_content_vprec',
#   'Heat_PmE',
#   'hfds',
#   'hfevapds',
#   'hfibthermds',
#   'hflso',
#   'hfrainds',
#   'hfrunoffds',
#   'hfsifrazil',
#   'hfsnthermds',
#   'hfsso',
#   'KE',
#   'LwLatSens',
#   'MEKE_KH',
#   'MEKE_Le',
#   'MEKE_Ue',
#   'MLD_003_max',
#   'MLD_003_min',
#   'MLD_003',
#   'mlotstmax',
#   'mlotstmin',
#   'mlotst',
#   'mlotstsq',
#   'MSTAR',
#   'net_heat_coupler',
#   'net_massin',
#   'net_massout',
#   'nonpenSW',
#   'opottempmint',
#   'opottemppmdiff_2d',
#   'opottemptend_2d',
#   'osaltpmdiff_2d',
#   'osalttend_2d',
#   'pbo',
#   'prlq',
#   'prsn',
#   'pso',
#   'rlntds',
#   'rsdo',
#   'rsntds',
#   'S_advection_xy_2d',
#   'salt_layer_ave',
#   'S_dfxy_conc_tendency',
#   'sfdsi',
#   'Sh_tendency_vert_remap_2d',
#   'sob',
#   'somint',
#   'so',
#   'sos',
#   'sossq',
#   'speed',
#   'S_tendency',
#   'S_tendency_vert_remap',
#   'subML_N2',
#   'T_advection_xy_2d',
#   'tauuo',
#   'tauvo',
#   'T_dfxy_conc_tendency',
#   'temp_layer_ave',
#   'thetao',
#   'thkcello',
#   'Th_tendency_vert_remap_2d',
#   'TKE_itidal',
#   'TKE_tidal',
#   'tnkebto',
#   'tob',
#   'tos_max',
#   'tos_min',
#   'tos',
#   'tossq',
#   'T_tendency',
#   'T_tendency_vert_remap',
#   'umo_2d',
#   'ustar',
#   'vmo_2d',
#   'volcello',
#   'wfo',
#   'zos',
#   'zossq'],
#  'ocean_annual_1x1deg': ['boundary_forcing_heat_tendency_2d',
#   'boundary_forcing_salt_tendency_2d',
#   'diftrelo',
#   'dispkexyfo',
#   'evs',
#   'ficeberg',
#   'frazil_heat_tendency_2d',
#   'friver',
#   'heat_content_cond',
#   'heat_content_fprec',
#   'heat_content_massin',
#   'heat_content_massout',
#   'heat_content_surfwater',
#   'heat_content_vprec',
#   'Heat_PmE',
#   'hfds',
#   'hfevapds',
#   'hfibthermds',
#   'hflso',
#   'hfrainds',
#   'hfrunoffds',
#   'hfsifrazil',
#   'hfsnthermds',
#   'hfsso',
#   'LwLatSens',
#   'mass_wt',
#   'MEKE_KH',
#   'MEKE_Le',
#   'MEKE_Ue',
#   'MLD_003_max',
#   'MLD_003_min',
#   'MLD_003',
#   'mlotstmax',
#   'mlotstmin',
#   'mlotst',
#   'mlotstsq',
#   'MSTAR',
#   'net_heat_coupler',
#   'net_massin',
#   'net_massout',
#   'nonpenSW',
#   'opottempmint',
#   'opottemptend_2d',
#   'osalttend_2d',
#   'pbo',
#   'prlq',
#   'prsn',
#   'pso',
#   'rlntds',
#   'rsntds',
#   'S_advection_xy_2d',
#   'sfdsi',
#   'Sh_tendency_vert_remap_2d',
#   'sob',
#   'somint',
#   'sos',
#   'sossq',
#   'speed',
#   'subML_N2',
#   'T_advection_xy_2d',
#   'Th_tendency_vert_remap_2d',
#   'TKE_itidal',
#   'TKE_tidal',
#   'tnkebto',
#   'tob',
#   'tos_max',
#   'tos_min',
#   'tos',
#   'tossq',
#   'ustar',
#   'wfo',
#   'zos',
#   'zossq'],
#  'ocean_annual_rho2': ['thkcello',
#   'uhGM',
#   'uhml',
#   'umo',
#   'vhGM',
#   'vhml',
#   'vmo',
#   'volcello',
#   'vo'],
#  'ocean_annual_rho2_1x1deg': ['thkcello', 'volcello'],
#  'ocean_annual_z': ['T_advection_xy',
#   'T_adx',
#   'osalttend',
#   'rsdoabsorb',
#   'S_advection_xy',
#   'S_adx',
#   'S_ady',
#   'Sh_tendency_vert_remap',
#   'so',
#   'so_xyave',
#   'T_ady',
#   'thetao',
#   'thetao_xyave',
#   'Th_tendency_vert_remap',
#   'uhGM',
#   'uhml',
#   'uh',
#   'umo',
#   'uo',
#   'vhGM',
#   'vhml',
#   'vh',
#   'vmo',
#   'volcello',
#   'vo',
#   'agessc',
#   'boundary_forcing_heat_tendency',
#   'boundary_forcing_salt_tendency',
#   'difmxybo',
#   'difmxylo',
#   'diftrblo',
#   'difvho',
#   'difvso',
#   'frazil_heat_tendency',
#   'Kd_BBL',
#   'Kd_ePBL',
#   'Kd_interface',
#   'Kd_itides',
#   'Kd_shear',
#   'obvfsq',
#   'opottempdiff',
#   'opottemppmdiff',
#   'opottemptend',
#   'osaltdiff',
#   'osaltpmdiff'],
#  'ocean_annual_z_1x1deg': ['agessc',
#   'boundary_forcing_heat_tendency',
#   'boundary_forcing_salt_tendency',
#   'difmxybo',
#   'difmxylo',
#   'diftrblo',
#   'difvho',
#   'difvso',
#   'frazil_heat_tendency',
#   'Kd_BBL',
#   'Kd_ePBL',
#   'Kd_interface',
#   'Kd_itides',
#   'Kd_shear',
#   'obvfsq',
#   'opottempdiff',
#   'opottemppmdiff',
#   'opottemptend',
#   'osaltdiff',
#   'osaltpmdiff',
#   'osalttend',
#   'rsdoabsorb',
#   'S_advection_xy',
#   'Sh_tendency_vert_remap',
#   'so',
#   'T_advection_xy',
#   'thetao',
#   'Th_tendency_vert_remap',
#   'volcello'],
#  'ocean_scalar_monthly': ['ave_wfo',
#   'LwLatSens_ga',
#   'masso',
#   'net_heat_coupler_ga',
#   'precip_ga',
#   'soga',
#   'sosga',
#   'ssh_ga',
#   'thetaoga',
#   'tosga',
#   'volo',
#   'ave_evs',
#   'ave_hfds',
#   'ave_hflso',
#   'ave_hfsso',
#   'ave_rlntds',
#   'ave_rsntds'],
#  'ocean_scalar_annual': ['ave_evs',
#   'ave_hfds',
#   'ave_hflso',
#   'ave_hfsso',
#   'ave_rlntds',
#   'ave_rsntds',
#   'ave_wfo',
#   'LwLatSens_ga',
#   'masso',
#   'net_heat_coupler_ga',
#   'precip_ga',
#   'soga',
#   'sosga',
#   'ssh_ga',
#   'thetaoga',
#   'tosga',
#   'volo'],
#  'ocean_Barents_opening': ['so', 'thetao', 'umo', 'uo', 'volcello'],
#  'ocean_Bering_Strait': ['so', 'thetao', 'vmo', 'volcello', 'vo'],
#  'ocean_Davis_Strait': ['so', 'thetao', 'vmo', 'volcello', 'vo'],
#  'ocean_Windward_Passage': ['so', 'thetao', 'vmo', 'volcello', 'vo'],
#  'ocean_Denmark_Strait': ['so', 'thetao', 'vmo', 'volcello', 'vo'],
#  'ocean_Drake_Passage': ['so', 'thetao', 'umo', 'uo', 'volcello'],
#  'ocean_English_Channel': ['so', 'thetao', 'umo', 'uo', 'volcello'],
#  'ocean_Faroe_Scotland': ['so', 'thetao', 'umo', 'uo', 'volcello'],
#  'ocean_Florida_Bahamas': ['so', 'thetao', 'vmo', 'volcello', 'vo'],
#  'ocean_Fram_Strait': ['volcello', 'vo', 'so', 'thetao', 'vmo'],
#  'ocean_Iceland_Faroe_V': ['vo', 'so', 'thetao', 'vmo', 'volcello'],
#  'ocean_Iceland_Faroe_U': ['so', 'thetao', 'umo', 'uo', 'volcello'],
#  'ocean_Indonesian_Throughflow': ['so', 'thetao', 'vmo', 'volcello', 'vo'],
#  'ocean_Mozambique_Channel': ['so', 'thetao', 'vmo', 'volcello', 'vo'],
#  'ocean_Pacific_undercurrent': ['so', 'thetao', 'umo', 'uo', 'volcello'],
#  'ocean_Taiwan_Luzon': ['so', 'thetao', 'umo', 'uo', 'volcello'],
#  'ocean_Agulhas_section': ['so', 'thetao', 'umo', 'uo', 'volcello'],
#  'ocean_Gibraltar_Strait': ['so', 'thetao', 'umo', 'uo', 'volcello'],
#  'ocean_Iceland_Norway': ['so', 'thetao', 'vmo', 'volcello', 'vo'],
#  'ocean_month_refined': ['hfbasin', 'hfx', 'hfy'],
#  'ocean_month_z_refined': ['msftyyz',
#   'msftyzmpa',
#   'msftyzsmpa',
#   'wmo',
#   'mfo_old',
#   'mfo',
#   'mfo_carribean_fix'],
#  'ocean_month_rho2_refined': ['msftyrhompa', 'msftyrho'],
#  'atmos_cmip': ['rlus',
#   'clt',
#   'hfls',
#   'hfss',
#   'prc',
#   'pr',
#   'prsn',
#   'rldscs',
#   'rlds',
#   'rsdscs',
#   'rsdsdiff',
#   'rsds',
#   'rsuscs',
#   'rsus',
#   'huss',
#   'ps',
#   'tas',
#   'tos',
#   'tslsi',
#   'uas',
#   'vas'],
#  'atmos': ['tm', 'u_ref', 'v_ref'],
#  'atmos_level_cmip': ['cli',
#   'cl',
#   'clw',
#   'ec550aer',
#   'mc',
#   'pfull',
#   'phalf',
#   'ps',
#   'rsdaf',
#   'rsdcsaf',
#   'rsdcs',
#   'rsd',
#   'rsuaf',
#   'rsucsaf',
#   'rsucs',
#   'rsu',
#   'tnhuspbl',
#   'tnhusscp',
#   'tntpbl',
#   'tntrlcs',
#   'tntrl',
#   'tntrscs',
#   'tntrs',
#   'tntscp'],
#  'atmos_level': ['precip',
#   'prec_ls',
#   'snow_conv',
#   'snow_ls',
#   'snow_tot',
#   'sphum',
#   'swdn_sfc_ad_clr',
#   'swdn_sfc_ad',
#   'swdn_sfc_clr',
#   'swdn_sfc',
#   'swdn_toa_clr',
#   'swdn_toa',
#   'swup_sfc_ad_clr',
#   'swup_sfc_ad',
#   'swup_sfc_clr',
#   'swup_sfc',
#   'swup_toa_ad_clr',
#   'swup_toa_ad',
#   'swup_toa_clr',
#   'swup_toa',
#   'tau_x',
#   'tau_y',
#   'tdt_dyn',
#   'temp',
#   'tot_cld_amt',
#   't_ref',
#   't_surf',
#   'ucomp',
#   'u_ref',
#   'uw_precip',
#   'vcomp',
#   'v_ref',
#   'wat_conv_col',
#   'wat_ls_col',
#   'wat_uw_col',
#   'wind_ref',
#   'WP_all_clouds',
#   'WVP',
#   'z_full',
#   'z_pbl',
#   'z_Ri_025',
#   'alb_sfc',
#   'aliq',
#   'cbmf_uwc',
#   'cld_amt',
#   'droplets',
#   'enth_conv_col',
#   'enth_ls_col',
#   'enth_uw_col',
#   'evap',
#   'high_cld_amt',
#   'ice_mask',
#   'ice_wat',
#   'IWP_all_clouds',
#   'IWP',
#   'liq_drp',
#   'liq_wat',
#   'low_cld_amt',
#   'lwdn_sfc_clr',
#   'lwdn_sfc',
#   'lwflx',
#   'LWP',
#   'lwsfc_ad_clr',
#   'lwsfc_ad',
#   'lwtoa_ad_clr',
#   'lwtoa_ad',
#   'lwup_sfc_clr',
#   'lwup_sfc',
#   'mid_cld_amt',
#   'olr_clr',
#   'olr',
#   'omega',
#   'prec_conv',
#   'prec_uwd',
#   'ps',
#   'qdt_dyn',
#   'qo3_col',
#   'q_ref',
#   'reff_modis2',
#   'reff_modis',
#   'rh_ref',
#   'shflx',
#   'slp_dyn',
#   'slp'],
#  'atmos_plev39_cmip': ['utendnogw',
#   'utendogw',
#   'va',
#   'zg',
#   'bry',
#   'ch4',
#   'cly',
#   'hcl',
#   'hno3',
#   'ho2',
#   'meanage',
#   'n2o',
#   'noy',
#   'o3',
#   'oh',
#   'ta',
#   'tntc',
#   'tntmp',
#   'tntnogw',
#   'tntogw',
#   'tntrlcs',
#   'tntrl',
#   'tntrscs',
#   'tntrs',
#   'tntscp',
#   'ua'],
#  'atmos_plev39_6hr': ['ta', 'ua', 'va', 'wap'],
#  'atmos_plev39_cmip_daily': ['ua', 'utendnogw', 'utendogw'],
#  'atmos_month_aer': ['aer_c',
#   'aer_ex_c_vs',
#   'aer_ex_vs',
#   'blk_crb_col',
#   'blk_crb_ex_c_vs',
#   'blk_crb',
#   'lg_dst_ex_c_vs',
#   'lg_dust_col',
#   'lg_dust',
#   'nh4no3_ex_c_vs',
#   'org_crb_col',
#   'org_crb_ex_c_vs',
#   'org_crb',
#   'ps',
#   'salt_col',
#   'salt_ex_c_vs',
#   'salt',
#   'sm_dst_ex_c_vs',
#   'sm_dust_col',
#   'sm_dust',
#   'sphum',
#   'sulfate_col',
#   'sulfate_ex_c_vs',
#   'sulfate',
#   'temp',
#   'vis_exopd_vl_c',
#   'aer_ab_c_vs',
#   'aer_ab_vs'],
#  'atmos_diurnal_cmip': ['rlutcs', 'rlut', 'rsdt', 'rsutcs', 'rsut'],
#  'atmos_diurnal': ['evspsbl', 'hfss', 'prc', 'pr', 'tas', 'z_Ri_025'],
#  'atmos_scalar': ['rlut',
#   'rsdt',
#   'rss',
#   'rsut',
#   'tasl',
#   'tas',
#   'ts',
#   'cfc113global',
#   'cfc11global',
#   'cfc12global',
#   'ch4global',
#   'CH4_lbc',
#   'co2mass',
#   'co2_tf',
#   'hcfc22global',
#   'n2oglobal',
#   'N2O_lbc',
#   'rrvch4',
#   'rrvco2',
#   'rrvf113',
#   'rrvf11',
#   'rrvf12',
#   'rrvf22',
#   'rrvn2o',
#   'solar_constant',
#   'hfls',
#   'hfss',
#   'prc',
#   'pr',
#   'prsn',
#   'rls'],
#  'tracer_level': ['dust5',
#   'flash_freq',
#   'aerosol_pH',
#   'AGE',
#   'aoanh',
#   'bcphil',
#   'bcphob',
#   'Bry',
#   'C10H16',
#   'CH2O',
#   'CH4_loss',
#   'CH4',
#   'cld_amt_chem',
#   'cloud_pHw',
#   'Cly',
#   'co2_flux_pcair_atm',
#   'CO_ddep',
#   'CO',
#   'CO_prod',
#   'dust1',
#   'dust2',
#   'dust3',
#   'dust4',
#   'gamma_so2',
#   'H2O2',
#   'HO2',
#   'hook_no',
#   'ISOP',
#   'LCH4_prod',
#   'loadnh3',
#   'loadnh4',
#   'loadnh4no3',
#   'loadso4',
#   'N2O',
#   'nh3dt_dyn',
#   'nh3_dvel',
#   'NH3_lossm',
#   'nh3_mol_flux_atm0',
#   'nh3_mol_flux',
#   'NH3',
#   'nh4dt_dyn',
#   'nh4_dvel',
#   'NH4',
#   'nh4no3dt_dyn',
#   'nh4no3_dvel',
#   'NH4NO3',
#   'nh50',
#   'N',
#   'NO2',
#   'NO',
#   'NOy',
#   'O1D',
#   'O3_chem_dt',
#   'O3_ddep',
#   'O3dt_dyn',
#   'O3',
#   'OH',
#   'omphil',
#   'omphob',
#   'Ox_loss',
#   'Ox_prod',
#   'PAN',
#   'PROD_SO4_H2O2',
#   'PROD_SO4_O3',
#   'ps',
#   'radon',
#   'rateconstant_N2O_O1D',
#   'rateconstant_N_NO2',
#   'SO2_evap_ls',
#   'SO2',
#   'SO2_prodm',
#   'SO4_ddep',
#   'SO4',
#   'SO4_prodm',
#   'SO4_wdep_all',
#   'SOA',
#   'sphum',
#   'ssalt1',
#   'ssalt2',
#   'ssalt3',
#   'ssalt4',
#   'ssalt5',
#   'ssalt_dvel',
#   'temp'],
#  'aerosol_cmip': ['loadbc',
#   'loaddust',
#   'loadnh4',
#   'loadno3',
#   'loadoa',
#   'loadpoa',
#   'loadso4',
#   'loadsoa',
#   'loadss',
#   'maxpblz_max',
#   'minpblz_min',
#   'od550aer',
#   'sfo3max',
#   'sfo3',
#   'sfpm25',
#   'toz',
#   'ua10',
#   'zg1000',
#   'zg100',
#   'zg10',
#   'zg500'],
#  'land': ['age',
#   'albedo_dif',
#   'albedo_dir',
#   'an_cl',
#   'an_op',
#   'area_ntrl',
#   'bl_max',
#   'bl',
#   'br_max',
#   'br',
#   'bseed',
#   'bsw',
#   'btot',
#   'bwood',
#   'carbon_cons',
#   'cleared_harv_pool_C',
#   'cleared_harv_rate_C',
#   'co2_mol_flux',
#   'con_g_h',
#   'con_v_h',
#   'con_v_v',
#   'crop_harv_pool_C',
#   'crop_harv_rate_C',
#   'crownarea',
#   'csmoke_rate',
#   'Ctot',
#   'cwlitt_C',
#   'dbh',
#   'evap_glac',
#   'evap_lake',
#   'evap_land',
#   'evap_soil',
#   'exudate',
#   'fco2',
#   'fevapg',
#   'fevapg_soil',
#   'fevaps',
#   'fevaps_soil',
#   'fevapv',
#   'fevapv_soil',
#   'flw',
#   'fprec_l',
#   'frunf',
#   'fsc',
#   'fsw',
#   'fuel',
#   'FWS',
#   'FWSv',
#   'gdd',
#   'glac_T',
#   'gpp',
#   'grnd_flux',
#   'height_ave',
#   'hevap',
#   'hprec',
#   'hrunf',
#   'lai',
#   'lake_dz',
#   'lake_K_z',
#   'lake_T',
#   'lake_wl',
#   'lake_ws',
#   'lambda',
#   'levapg',
#   'levapg_soil',
#   'levaps',
#   'levaps_soil',
#   'levapv',
#   'levapv_soil',
#   'lflitt_C',
#   'lwdn',
#   'LWS',
#   'LWSv',
#   'meltg_glac',
#   'melt',
#   'melts',
#   'ncohorts',
#   'nep',
#   'nindivs',
#   'nlayers',
#   'npp',
#   'nsc',
#   'PAR_dn',
#   'PAR_net',
#   'past_harv_pool_C',
#   'past_harv_rate_C',
#   'precip',
#   'qca',
#   'qco2_dvmr',
#   'resg',
#   'resp',
#   'rhiz_exud_C',
#   'rsoil_fast',
#   'rsoil',
#   'rsoil_slow',
#   'runf',
#   'sai',
#   'sens',
#   'shflx',
#   'snow_glac',
#   'snow_lake',
#   'snow',
#   'snow_soil',
#   'soil_C',
#   'soil_fsat',
#   'soil_ice',
#   'soil_liq',
#   'soil_psi',
#   'soil_psi_n',
#   'soil_rbf',
#   'soil_rie',
#   'soil_rnu',
#   'soil_rsn',
#   'soil_T',
#   'soil_uptk',
#   'soil_uptk_ntrl',
#   'soil_water_supply',
#   'soil_wt_4',
#   'species',
#   'ssc',
#   'stomatal_cond',
#   'swdn_dif',
#   'swdn_dir',
#   'swup_dif',
#   'swup_dir',
#   'Tca',
#   'tc_pheno',
#   'Tgrnd',
#   'theta',
#   'theta_phen',
#   'tot_soil_C',
#   'Trad',
#   'transp',
#   't_ref',
#   'tsoil_av',
#   'vegn_height',
#   'vegn_rden',
#   'vegn_rzeta',
#   'vegn_sncrit',
#   'vegn_T',
#   'water_cons',
#   'water_lake',
#   'water_soil',
#   'wl',
#   'wood_fast_harv_pool_C',
#   'wood_fast_harv_rate_C',
#   'wood_med_harv_pool_C',
#   'wood_med_harv_rate_C',
#   'wood_slow_harv_pool_C',
#   'wood_slow_harv_rate_C',
#   'w_scale',
#   'ws'],
#  'land_cubic': ['tile1', 'tile2', 'tile3', 'tile4', 'tile5', 'tile6'],
#  'land_instant_cubic': ['tile6', 'tile1', 'tile2', 'tile3', 'tile4', 'tile5'],
#  'land_cmip': ['mrro', 'mrsos'],
#  'land_dust': ['dust_wdep_ntrl',
#   'dust_wdep_past',
#   'area_crop',
#   'area_ntrl',
#   'area_past',
#   'area_range',
#   'area_scnd',
#   'bareness_crop',
#   'bareness',
#   'bareness_ntrl',
#   'bareness_past',
#   'bareness_range',
#   'bareness_scnd',
#   'dust_ddep_crop',
#   'dust_ddep_glac',
#   'dust_ddep_lake',
#   'dust_ddep',
#   'dust_ddep_ntrl',
#   'dust_ddep_past',
#   'dust_ddep_range',
#   'dust_ddep_scnd',
#   'dust_emis_crop',
#   'dust_emis_glac',
#   'dust_emis_lake',
#   'dust_emis',
#   'dust_emis_ntrl',
#   'dust_emis_past',
#   'dust_emis_range',
#   'dust_emis_scnd',
#   'dust_fatm_crop',
#   'dust_fatm_glac',
#   'dust_fatm_lake',
#   'dust_fatm',
#   'dust_fatm_ntrl',
#   'dust_fatm_past',
#   'dust_fatm_range',
#   'dust_fatm_scnd',
#   'dust_wdep_crop',
#   'dust_wdep_glac',
#   'dust_wdep_lake',
#   'dust_wdep',
#   'dust_wdep_range',
#   'dust_wdep_scnd',
#   'frac_crop',
#   'frac_ntrl',
#   'frac_past',
#   'frac_range',
#   'frac_scnd',
#   'height',
#   'lai',
#   'sai',
#   'snow_fmass',
#   'soil_iceness_crop',
#   'soil_iceness',
#   'soil_iceness_ntrl',
#   'soil_iceness_past',
#   'soil_iceness_range',
#   'soil_iceness_scnd',
#   'soil_wetness_crop',
#   'soil_wetness',
#   'soil_wetness_ntrl',
#   'soil_wetness_past',
#   'soil_wetness_range',
#   'soil_wetness_scnd',
#   'u_ts_crop',
#   'u_ts',
#   'u_ts_ntrl',
#   'u_ts_past',
#   'u_ts_range',
#   'u_ts_scnd',
#   'w10m',
#   'z0m'],
#  'river': ['rv_d_h2o', 'rv_o_h2o'],
#  'river_cubic': ['tile1', 'tile2', 'tile3', 'tile4', 'tile5', 'tile6'],
#  'river_instant_cubic': ['tile1', 'tile2', 'tile3', 'tile4', 'tile5', 'tile6'],
#  'LUmip_month_psl': ['area',
#   'gppLut',
#   'hflsLut',
#   'hfssLut',
#   'hussLut',
#   'laiLut',
#   'mrroLut',
#   'mrs1mLut',
#   'mrsoLut',
#   'mrsosLut',
#   'nppLut',
#   'raLut',
#   'rhLut',
#   'rlusLut',
#   'rsusLut',
#   'tasLut',
#   'tslsiLut'],
#  'LUmip_month_crp': ['hussLut',
#   'laiLut',
#   'mrroLut',
#   'mrs1mLut',
#   'mrsoLut',
#   'mrsosLut',
#   'nppLut',
#   'raLut',
#   'rhLut',
#   'rlusLut',
#   'rsusLut',
#   'tasLut',
#   'tslsiLut',
#   'area',
#   'gppLut',
#   'hflsLut',
#   'hfssLut'],
#  'LUmip_month_pst': ['rhLut',
#   'rlusLut',
#   'rsusLut',
#   'tasLut',
#   'tslsiLut',
#   'area',
#   'gppLut',
#   'hflsLut',
#   'hfssLut',
#   'hussLut',
#   'laiLut',
#   'mrroLut',
#   'mrs1mLut',
#   'mrsoLut',
#   'mrsosLut',
#   'nppLut',
#   'raLut'],
#  'LUmip_refined': ['raLut',
#   'area',
#   'fracLut',
#   'gppLut',
#   'hflsLut',
#   'hfssLut',
#   'hussLut',
#   'laiLut',
#   'mrroLut',
#   'mrs1mLut',
#   'mrsoLut',
#   'mrsosLut',
#   'nppLut',
#   'rhLut',
#   'rlusLut',
#   'rsusLut',
#   'tasLut',
#   'tslsiLut'],
#  'LUmip_year_psl': ['area',
#   'cSoilLut',
#   'cVegLut',
#   'fracInLut',
#   'fracLut',
#   'fracOutLut',
#   'cSoil',
#   'cVeg'],
#  'LUmip_year_crp': ['area',
#   'cSoilLut',
#   'cVegLut',
#   'fracInLut',
#   'fracLut',
#   'fracOutLut'],
#  'LUmip_year_pst': ['area',
#   'cSoilLut',
#   'cVegLut',
#   'fracInLut',
#   'fracLut',
#   'fracOutLut'],
#  'land_by_species': ['age',
#   'an_cl',
#   'an_op',
#   'bl_max',
#   'bl',
#   'br_max',
#   'br',
#   'bseed',
#   'bsw',
#   'btot',
#   'bwood',
#   'crownarea',
#   'dbh',
#   'exudate',
#   'gpp',
#   'height_ave',
#   'lai',
#   'leafarea',
#   'ncohorts',
#   'nindivs',
#   'nsc',
#   'PAR_dn',
#   'PAR_net',
#   'resp',
#   'rhiz_exud_C',
#   'sai',
#   'Tvegn',
#   'w_scale',
#   'npp'],
#  'fire': ['BAperFire_0',
#   'BAperFire_1',
#   'BAperFire_2',
#   'BAperFire_3',
#   'BAperFire_max',
#   'BA_rate',
#   'BF_rate',
#   'burnable_frac',
#   'crown_scorch_frac',
#   'Fcrop',
#   'fire_agb',
#   'fire_depth_ave',
#   'fire_duration_ave',
#   'fire_fn_agb',
#   'fire_fn_GDPpc_BA',
#   'fire_fn_GDPpc_NF',
#   'fire_fn_popD_BA',
#   'fire_fn_popD_NF',
#   'fire_fn_rh_max',
#   'fire_fn_rh_min',
#   'fire_fn_rh',
#   'fire_fn_Tca',
#   'fire_fn_theta',
#   'fire_intensity',
#   'fire_rh_max',
#   'fire_rh_min',
#   'fire_rh',
#   'fire_Tca',
#   'fire_theta',
#   'Fpast',
#   'fragmenting_frac',
#   'GDPpc',
#   'HB',
#   'Ia',
#   'In',
#   'LB',
#   'lightning',
#   'multiday_fire_BA',
#   'multiday_fire_Nfires',
#   'Nfire_perKm2',
#   'Nfire_rate',
#   'population',
#   'ROS',
#   'wind_forFire'],
#  'aerosol_hourly_cmip': ['ps', 'sfno2', 'sfo3', 'sfpm25', 'tas'],
#  'atmos_co2_level': ['co2_dvmr',
#   'co2_flux',
#   'co2_mol_flux',
#   'co2_restore',
#   'co2_surf_dvmr',
#   'ps',
#   'pwt',
#   'sphum',
#   'XCO2',
#   'co23D',
#   'co2_atm_dvmr'],
#  'ocean_cobalt_sfc': ['runoff_flux_fed',
#   'runoff_flux_ldon',
#   'runoff_flux_ldop',
#   'runoff_flux_lith',
#   'runoff_flux_ndet',
#   'runoff_flux_no3',
#   'runoff_flux_po4',
#   'runoff_flux_sldon',
#   'runoff_flux_sldop',
#   'runoff_flux_srdon',
#   'runoff_flux_srdop',
#   'sfc_def_fe_di',
#   'sfc_def_fe_lgp',
#   'sfc_def_fe_smp',
#   'sfc_felim_di',
#   'sfc_felim_lgp',
#   'sfc_felim_smp',
#   'sfc_irrlim_di',
#   'sfc_irrlim_lgp',
#   'sfc_irrlim_smp',
#   'sfc_mu_di',
#   'sfc_mu_lgp',
#   'sfc_mu_smp',
#   'sfc_nh4lim_lgp',
#   'sfc_nh4lim_smp',
#   'sfc_no3lim_lgp',
#   'sfc_no3lim_smp',
#   'sfc_po4lim_di',
#   'sfc_po4lim_lgp',
#   'sfc_po4lim_smp',
#   'sfc_q_fe_2_n_di',
#   'sfc_q_fe_2_n_lgp',
#   'sfc_q_fe_2_n_smp',
#   'sfc_theta_di',
#   'sfc_theta_lgp',
#   'sfc_theta_smp',
#   'dep_dry_fed',
#   'dep_dry_lith',
#   'dep_dry_nh4',
#   'dep_dry_no3',
#   'dep_dry_po4',
#   'dep_wet_fed',
#   'dep_wet_lith',
#   'dep_wet_nh4',
#   'dep_wet_no3',
#   'dep_wet_po4',
#   'dic_csurf',
#   'dic_deltap',
#   'dic_kw',
#   'dic_sc_no',
#   'dic_stf_gas',
#   'ffe_iceberg',
#   'nh4_alpha',
#   'nh4_csurf',
#   'nh4_deltap',
#   'nh4_kw',
#   'nh4_sc_no',
#   'nh4_stf_gas',
#   'nh4_stf',
#   'o2_alpha',
#   'o2_csurf',
#   'o2_deltap',
#   'o2_kw',
#   'o2_sc_no',
#   'o2_stf_gas',
#   'pco2surf',
#   'pka_nh3',
#   'pnh3surf',
#   'runoff_flux_alk',
#   'runoff_flux_dic'],
#  'ocean_cobalt_btm': ['fpdet_burial',
#   'fsidet_btm',
#   'cased_redis_coef',
#   'cased_redis_delz',
#   'fcadet_arag_btm',
#   'btm_co3_sol_calc',
#   'btm_htotal',
#   'btm_o2',
#   'btm_temp',
#   'cased',
#   'btm_co3_ion',
#   'btm_co3_sol_arag',
#   'fcadet_calc_btm',
#   'fcased_burial',
#   'fcased_redis',
#   'fcased_redis_surfresp',
#   'ffedet_btm',
#   'ffe_geotherm',
#   'ffe_sed',
#   'flithdet_btm',
#   'fndet_btm',
#   'fndet_burial',
#   'fnfeso4red_sed',
#   'fno3denit_sed',
#   'fnoxic_sed',
#   'fpdet_btm'],
#  'ocean_cobalt_fdet_100': ['fcadet_arag_100',
#   'fcadet_calc_100',
#   'ffedet_100',
#   'flithdet_100',
#   'fndet_100',
#   'fpdet_100',
#   'fsidet_100'],
#  'ocean_cobalt_tracers_int': ['wc_vert_int_poc',
#   'wc_vert_int_si',
#   'don_100',
#   'mesozoo_200',
#   'nbact_100',
#   'ndet_100',
#   'ndi_100',
#   'nlgp_100',
#   'nlgz_100',
#   'nmdz_100',
#   'nsmp_100',
#   'nsmz_100',
#   'silgp_100',
#   'wc_vert_int_alk',
#   'wc_vert_int_c',
#   'wc_vert_int_dic',
#   'wc_vert_int_doc',
#   'wc_vert_int_fe',
#   'wc_vert_int_n',
#   'wc_vert_int_o2',
#   'wc_vert_int_p'],
#  'ocean_cobalt_fluxes_int': ['jaggloss_nlgp_100',
#   'jaggloss_nsmp_100',
#   'jexuloss_ndi_100',
#   'jexuloss_nlgp_100',
#   'jexuloss_nsmp_100',
#   'jhploss_nlgz_100',
#   'jhploss_nmdz_100',
#   'jingest_n_hp_100',
#   'jingest_n_nlgz_100',
#   'jingest_n_nmdz_100',
#   'jingest_n_nsmz_100',
#   'jprod_cadet_arag_100',
#   'jprod_cadet_calc_100',
#   'jprod_don_nmdz_100',
#   'jprod_don_nsmz_100',
#   'jprod_lithdet_100',
#   'jprod_mesozoo_200',
#   'jprod_nbact_100',
#   'jprod_ndet_hp_100',
#   'jprod_ndet_nlgz_100',
#   'jprod_ndet_nmdz_100',
#   'jprod_ndi_100',
#   'jprod_ndi_n2_100',
#   'jprod_ndi_new_100',
#   'jprod_nlgp_100',
#   'jprod_nlgp_new_100',
#   'jprod_nlgz_100',
#   'jprod_nmdz_100',
#   'jprod_nsmp_100',
#   'jprod_nsmp_new_100',
#   'jprod_nsmz_100',
#   'jprod_sidet_100',
#   'jremin_ndet_100',
#   'jremin_n_hp_100',
#   'jremin_n_nbact_100',
#   'jremin_n_nlgz_100',
#   'jremin_n_nmdz_100',
#   'jremin_n_nsmz_100',
#   'juptake_ldon_nbact_100',
#   'jvirloss_nbact_100',
#   'jvirloss_nsmp_100',
#   'jzloss_nbact_100',
#   'jzloss_ndi_100',
#   'jzloss_nlgp_100',
#   'jzloss_nmdz_100',
#   'jzloss_nsmp_100',
#   'jzloss_nsmz_100',
#   'wc_vert_int_jdiss_cadet',
#   'wc_vert_int_jdiss_sidet',
#   'wc_vert_int_jnitrif',
#   'wc_vert_int_jno3denit',
#   'wc_vert_int_jo2resp',
#   'wc_vert_int_jprod_cadet',
#   'wc_vert_int_jprod_nh4',
#   'wc_vert_int_juptake_nh4',
#   'wc_vert_int_juptake_no3',
#   'wc_vert_int_nfix'],
#  'ocean_cobalt_tracers_year_z': ['fe_sol',
#   'kfe_eq_lig',
#   'cadet_arag',
#   'cadet_calc',
#   'fedet',
#   'feprime',
#   'ldon',
#   'ldop',
#   'ligand',
#   'lithdet',
#   'lith',
#   'omega_arag',
#   'omega_calc',
#   'pdet',
#   'sidet',
#   'silg',
#   'sldon',
#   'sldop',
#   'srdon',
#   'srdop',
#   'volcello'],
#  'ocean_cobalt_omip_daily': ['chlos', 'mesozoo_200', 'phycos'],
#  'ocean_cobalt_omip_sfc': ['aragos',
#   'baccos',
#   'bfeos',
#   'bsios',
#   'calcos',
#   'chldiatos',
#   'chldiazos',
#   'chlmiscos',
#   'chlos',
#   'chlpicoos',
#   'co3os',
#   'co3sataragos',
#   'co3satcalcos',
#   'detocos',
#   'dfeos',
#   'dissicos',
#   'dissocos',
#   'nh4os',
#   'no3os',
#   'o2os',
#   'o2satos',
#   'phos',
#   'phycos',
#   'phydiatos',
#   'phydiazos',
#   'phyfeos',
#   'phymiscos',
#   'phynos',
#   'phypicoos',
#   'phypos',
#   'physios',
#   'po4os',
#   'ponos',
#   'popos',
#   'sios',
#   'talkos',
#   'zmesoos',
#   'zmicroos',
#   'zoocos'],
#  'ocean_cobalt_omip_2d': ['fsn',
#   'icfriver',
#   'intdic',
#   'intdoc',
#   'intparag',
#   'intpbfe',
#   'intpbn',
#   'intpbp',
#   'intpbsi',
#   'intpcalcite',
#   'intpn2',
#   'intpoc',
#   'intppdiat',
#   'intppdiaz',
#   'intppmisc',
#   'intpp',
#   'intppnitrate',
#   'intpppico',
#   'limfediat',
#   'limfediaz',
#   'limfemisc',
#   'limfepico',
#   'limirrdiat',
#   'limirrdiaz',
#   'limirrmisc',
#   'limirrpico',
#   'limndiat',
#   'limnmisc',
#   'limnpico',
#   'limpdiat',
#   'limpdiaz',
#   'limpmisc',
#   'limppico',
#   'ocfriver',
#   'spco2',
#   'dpco2',
#   'dpo2',
#   'eparag100',
#   'epc100',
#   'epcalc100',
#   'epfe100',
#   'epn100',
#   'epp100',
#   'epsi100',
#   'fgco2',
#   'fgo2',
#   'frfe',
#   'fric',
#   'frn',
#   'froc',
#   'fsfe'],
#  'ocean_cobalt_omip_tracers_month_z': ['chl',
#   'co3',
#   'co3satarag',
#   'co3satcalc',
#   'dfe',
#   'dissic',
#   'dissoc',
#   'expc',
#   'graz',
#   'nh4',
#   'no3',
#   'o2',
#   'o2sat',
#   'ph',
#   'phyc',
#   'phydiat',
#   'phydiaz',
#   'phymisc',
#   'phypico',
#   'po4',
#   'pon',
#   'pp',
#   'si',
#   'talk',
#   'volcello',
#   'zmeso',
#   'zmicro',
#   'zooc'],
#  'ocean_cobalt_omip_tracers_year_z': ['arag',
#   'bacc',
#   'bfe',
#   'bsi',
#   'calc',
#   'chldiat',
#   'chldiaz',
#   'chlmisc',
#   'chl',
#   'chlpico',
#   'co3',
#   'co3satarag',
#   'co3satcalc',
#   'detoc',
#   'dfe',
#   'dissic',
#   'dissoc',
#   'nh4',
#   'no3',
#   'o2',
#   'o2sat',
#   'ph',
#   'phyc',
#   'phydiat',
#   'phydiaz',
#   'phyfe',
#   'phymisc',
#   'phyn',
#   'phypico',
#   'phyp',
#   'physi',
#   'po4',
#   'pon',
#   'pop',
#   'si',
#   'talk',
#   'volcello',
#   'zmeso',
#   'zmicro',
#   'zooc'],
#  'ocean_cobalt_omip_rates_year_z': ['bddtalk',
#   'bddtdic',
#   'bddtdife',
#   'bddtdin',
#   'bddtdip',
#   'bddtdisi',
#   'darag',
#   'dcalc',
#   'exparag',
#   'expcalc',
#   'expc',
#   'expfe',
#   'expn',
#   'expp',
#   'expsi',
#   'fediss',
#   'fescav',
#   'graz',
#   'parag',
#   'pbfe',
#   'pbsi',
#   'pcalc',
#   'pnitrate',
#   'ppdiat',
#   'ppdiaz',
#   'ppmisc',
#   'pp',
#   'pppico',
#   'remoc',
#   'volcello'],
#  'ocean_cobalt_omip_daily_1x1deg': ['chlos', 'mesozoo_200', 'phycos'],
#  'ocean_cobalt_omip_sfc_1x1deg': ['chldiazos',
#   'chlmiscos',
#   'chlos',
#   'chlpicoos',
#   'co3os',
#   'co3sataragos',
#   'co3satcalcos',
#   'detocos',
#   'dfeos',
#   'dissicos',
#   'dissocos',
#   'nh4os',
#   'no3os',
#   'o2os',
#   'o2satos',
#   'phos',
#   'phycos',
#   'phydiatos',
#   'phydiazos',
#   'phyfeos',
#   'phymiscos',
#   'phynos',
#   'phypicoos',
#   'phypos',
#   'physios',
#   'po4os',
#   'ponos',
#   'popos',
#   'sios',
#   'talkos',
#   'zmesoos',
#   'zmicroos',
#   'zoocos',
#   'aragos',
#   'baccos',
#   'bfeos',
#   'bsios',
#   'calcos',
#   'chldiatos',
#   'chldiazos_orig',
#   'chlmiscos_orig',
#   'dissocos_orig',
#   'phypos_orig',
#   'chlpicoos_orig',
#   'chldiatos_orig'],
#  'ocean_cobalt_omip_2d_1x1deg': ['dpco2',
#   'dpo2',
#   'eparag100',
#   'epc100',
#   'epcalc100',
#   'epfe100',
#   'epn100',
#   'fric',
#   'frn',
#   'froc',
#   'fsfe',
#   'fsn',
#   'icfriver',
#   'intdic',
#   'intdoc',
#   'intparag',
#   'intpbfe',
#   'intpbn',
#   'intpbp',
#   'intpbsi',
#   'intpcalcite',
#   'intpn2',
#   'intpoc',
#   'intppdiat',
#   'intppdiaz',
#   'intppmisc',
#   'intpp',
#   'intppnitrate',
#   'intpppico',
#   'limfediat',
#   'limfediaz',
#   'limfemisc',
#   'limfepico',
#   'limirrdiat',
#   'limirrdiaz',
#   'limirrmisc',
#   'limirrpico',
#   'limndiat',
#   'limnmisc',
#   'limnpico',
#   'limpdiat',
#   'limpdiaz',
#   'limpmisc',
#   'limppico',
#   'ocfriver',
#   'spco2',
#   'epp100',
#   'epsi100',
#   'fgco2',
#   'fgo2',
#   'frfe',
#   'intpbp_orig',
#   'intdoc_orig'],
#  'ocean_cobalt_omip_tracers_month_z_1x1deg': ['chl',
#   'co3',
#   'co3satarag',
#   'co3satcalc',
#   'dfe',
#   'dissic',
#   'dissoc',
#   'expc',
#   'graz',
#   'nh4',
#   'no3',
#   'o2',
#   'o2sat',
#   'ph',
#   'phyc',
#   'phydiat',
#   'phydiaz',
#   'phymisc',
#   'phypico',
#   'po4',
#   'pon',
#   'pp',
#   'si',
#   'talk',
#   'volcello',
#   'zmeso',
#   'zmicro',
#   'zooc',
#   'dissoc_orig'],
#  'ocean_cobalt_omip_tracers_year_z_1x1deg': ['phyc',
#   'phydiat',
#   'phydiaz',
#   'phyfe',
#   'phymisc',
#   'phyn',
#   'phypico',
#   'phyp',
#   'physi',
#   'po4',
#   'pon',
#   'pop',
#   'si',
#   'talk',
#   'volcello',
#   'zmeso',
#   'zmicro',
#   'arag',
#   'bacc',
#   'bfe',
#   'bsi',
#   'calc',
#   'chldiat',
#   'chldiaz',
#   'chlmisc',
#   'chl',
#   'chlpico',
#   'co3',
#   'co3satarag',
#   'co3satcalc',
#   'detoc',
#   'dfe',
#   'dissic',
#   'dissoc_orig',
#   'o2',
#   'o2sat',
#   'ph',
#   'zooc',
#   'nh4',
#   'no3',
#   'dissoc'],
#  'ocean_cobalt_omip_rates_year_z_1x1deg': ['bddtalk',
#   'bddtdic',
#   'bddtdife',
#   'bddtdin',
#   'bddtdip',
#   'bddtdisi',
#   'darag',
#   'dcalc',
#   'exparag',
#   'expcalc',
#   'expc',
#   'expfe',
#   'expn',
#   'expp',
#   'expsi',
#   'fediss',
#   'fescav',
#   'graz',
#   'parag',
#   'pbfe',
#   'pbsi',
#   'pcalc',
#   'pnitrate',
#   'ppdiat',
#   'ppdiaz',
#   'ppmisc',
#   'pp',
#   'pppico',
#   'remoc',
#   'volcello'],
#  'ocean_inert_month': ['cfc11_alpha',
#   'cfc11_csurf',
#   'cfc11',
#   'cfc11_sc_no',
#   'cfc11_stf_gas',
#   'cfc12_alpha',
#   'cfc12_csurf',
#   'cfc12',
#   'cfc12_sc_no',
#   'cfc12_stf_gas',
#   'fgcfc11',
#   'fgcfc12',
#   'fgsf6',
#   'sf6_alpha',
#   'sf6_csurf',
#   'sf6',
#   'sf6_sc_no',
#   'sf6_stf_gas',
#   'volcello'],
#  'ocean_inert_month_1x1deg': ['cfc11_alpha',
#   'cfc11_csurf',
#   'cfc11',
#   'cfc11_sc_no',
#   'cfc11_stf_gas',
#   'cfc12_alpha',
#   'cfc12_csurf',
#   'cfc12',
#   'cfc12_sc_no',
#   'cfc12_stf_gas',
#   'fgcfc11',
#   'fgcfc12',
#   'fgsf6',
#   'sf6_alpha',
#   'sf6_csurf',
#   'sf6',
#   'sf6_sc_no',
#   'sf6_stf_gas',
#   'volcello'],
#  'ocean_inert_z': ['cfc12', 'sf6', 'volcello', 'cfc11'],
#  'ocean_inert_z_1x1deg': ['cfc11', 'cfc12', 'sf6', 'volcello'],
#  'atmos_cmip_Plev8': ['ta', 'ua', 'va', 'wap', 'hur', 'hus', 'zg'],
#  'ice': ['IX_TRANS',
#   'EXT_MIN',
#   'EXT',
#   'FA_X',
#   'FA_Y',
#   'FI_X',
#   'FI_Y',
#   'FRAZIL',
#   'IY_TRANS',
#   'LH',
#   'LSNK',
#   'LSRC',
#   'LW',
#   'MIB',
#   'RAIN',
#   'RUNOFF',
#   'SALTF',
#   'SH',
#   'simass',
#   'sisnmass',
#   'sisnthick',
#   'sispeed',
#   'sithick',
#   'sitimefrac',
#   'siu',
#   'siv',
#   'SN2IC',
#   'SNOWFL',
#   'SSH',
#   'SSS',
#   'SST',
#   'STRENGTH_hf',
#   'SW',
#   'T1',
#   'T2',
#   'T3',
#   'T4',
#   'TMELT',
#   'TSN',
#   'UO',
#   'VO',
#   'XPRT',
#   'ALB',
#   'BHEAT',
#   'BMELT',
#   'BSNK',
#   'CALVING_HFLX',
#   'CALVING',
#   'CN',
#   'E2MELT',
#   'EVAP',
#   'EXT_MAX',
#   'siconc',
#   'sisnconc_old',
#   'siconc_old',
#   'sitemptop_old',
#   'sivol_old',
#   'sisnconc',
#   'sitemptop',
#   'sivol'],
#  'ice_1x1deg': ['TMELT',
#   'CN',
#   'E2MELT',
#   'EVAP',
#   'EXT_MAX',
#   'EXT_MIN',
#   'EXT',
#   'FRAZIL',
#   'LH',
#   'ALB',
#   'LSNK',
#   'BHEAT',
#   'LSRC',
#   'BMELT',
#   'LW',
#   'BSNK',
#   'CALVING_HFLX',
#   'MIB',
#   'CALVING',
#   'RAIN',
#   'RUNOFF',
#   'SALTF',
#   'SH',
#   'simass',
#   'sisnmass',
#   'sisnthick',
#   'sispeed',
#   'sithick',
#   'sitimefrac',
#   'SN2IC',
#   'SNOWFL',
#   'SSH',
#   'SSS',
#   'SST',
#   'STRENGTH_hf',
#   'SW',
#   'T1',
#   'T2',
#   'T3',
#   'T4',
#   'TSN',
#   'XPRT',
#   'siconc_old',
#   'sisnconc_old',
#   'sitemptop_old',
#   'siconc',
#   'sisnconc',
#   'sitemptop',
#   'sivol_old',
#   'sivol'],
#  'LUmip_refined_year': ['area',
#   'cSoilLut',
#   'cVegLut',
#   'fracInLut',
#   'fracOutLut',
#   'fracLut',
#   'cSoil',
#   'cVeg']}

# %% [markdown]
# #### Find ppname for specific variable

# %%
gu.core.find_variable(pp,'thetao')
# Out:
# ['ocean_monthly_z',
#  'ocean_monthly_z_1x1deg',
#  'ocean_annual',
#  'ocean_annual_z',
#  'ocean_annual_z_1x1deg',
#  'ocean_Barents_opening',
#  'ocean_Bering_Strait',
#  'ocean_Davis_Strait',
#  'ocean_Windward_Passage',
#  'ocean_Denmark_Strait',
#  'ocean_Drake_Passage',
#  'ocean_English_Channel',
#  'ocean_Faroe_Scotland',
#  'ocean_Florida_Bahamas',
#  'ocean_Fram_Strait',
#  'ocean_Iceland_Faroe_V',
#  'ocean_Iceland_Faroe_U',
#  'ocean_Indonesian_Throughflow',
#  'ocean_Mozambique_Channel',
#  'ocean_Pacific_undercurrent',
#  'ocean_Taiwan_Luzon',
#  'ocean_Agulhas_section',
#  'ocean_Gibraltar_Strait',
#  'ocean_Iceland_Norway']

# %% [markdown]
# #### Display variables in specific ppname

# %%
gu.core.get_varnames(pp,'ocean_cobalt_omip_tracers_year_z_1x1deg')
# Out:
# ['arag',
#  'bacc',
#  'bfe',
#  'bsi',
#  'calc',
#  'chldiat',
#  'chldiaz',
#  'chlmisc',
#  'chl',
#  'chlpico',
#  'co3',
#  'co3satarag',
#  'co3satcalc',
#  'detoc',
#  'dfe',
#  'dissic',
#  'nh4',
#  'no3',
#  'o2',
#  'o2sat',
#  'ph',
#  'phyc',
#  'phydiat',
#  'phydiaz',
#  'phyfe',
#  'phymisc',
#  'phyn',
#  'phypico',
#  'phyp',
#  'physi',
#  'po4',
#  'pon',
#  'pop',
#  'si',
#  'talk',
#  'volcello',
#  'zmeso',
#  'zmicro',
#  'zooc',
#  'dissoc_orig',
#  'dissoc']

# %% [markdown]
# ### SPECIFY

# %%
ppname = 'ocean_cobalt_omip_tracers_year_z_1x1deg'
out = 'ts'
add = ['o2','o2sat'] # type : list; can specify multiple variables if same ppname
time = '*'

# %%
filename = '.'.join([ppname,out,'zarr'])

# %%
# Check that requested variables are in ppname
available = gu.core.get_varnames(pp,ppname)
for a in add:
    if a not in available:
        raise Error(a + " not in " + ppname)

# %%
if os.path.exists(outdir):
    print("Directory exists : "+outdir)
else:
    print("Creating directory : "+outdir)
    os.mkdir(outdir)

outpath = outdir+filename
if os.path.exists(outpath):
    print("zarr store exists : "+outpath)
    print("Variables will be appended.")
else:
    print("zarr store will be created : "+outpath)
# Out:
# Creating directory : /work/gam/zarr/ESM4_1pctCO2_D1/
# zarr store will be created : /work/gam/zarr/ESM4_1pctCO2_D1/ocean_cobalt_omip_tracers_year_z_1x1deg.ts.zarr

# %% [markdown]
# ### DMGET

# %%
local = gu.core.get_local(pp,ppname,out)

# %%
if len(add)==1:
    path = gu.core.get_pathspp(pp,ppname,out,local,time,add[0])
    gu.core.issue_dmget(path)
else:
    for a in add:
        path = gu.core.get_pathspp(pp,ppname,out,local,time,a)
        gu.core.issue_dmget(path)

# %%
gu.core.query_dmget()
# Out:
# 1

# %%
# Snippet of code that will only complete when out of queue
count = 0
while gu.core.query_dmget()==1:
    count+=1
    if count%100==0:
        print("Still in queue at :")
        print(datetime.datetime.now())
# Out:
# Still in queue at :
# 2022-12-09 16:15:17.990821
# Still in queue at :
# 2022-12-09 16:15:21.451076
# Still in queue at :
# 2022-12-09 16:15:25.027338
# Still in queue at :
# 2022-12-09 16:15:28.547143
# Still in queue at :
# 2022-12-09 16:15:32.023771
# Still in queue at :
# 2022-12-09 16:15:35.519981
# Still in queue at :
# 2022-12-09 16:15:39.104946
# Still in queue at :
# 2022-12-09 16:15:42.585137
# Still in queue at :
# 2022-12-09 16:15:46.103619
# Still in queue at :
# 2022-12-09 16:15:49.601061
# Still in queue at :
# 2022-12-09 16:15:53.091659
# Still in queue at :
# 2022-12-09 16:15:56.582695
# Still in queue at :
# 2022-12-09 16:16:00.085743
# Still in queue at :
# 2022-12-09 16:16:03.621650
# Still in queue at :
# 2022-12-09 16:16:07.153404
# Still in queue at :
# 2022-12-09 16:16:10.687564
# Still in queue at :
# 2022-12-09 16:16:14.257226
# Still in queue at :
# 2022-12-09 16:16:17.752217
# Still in queue at :
# 2022-12-09 16:16:21.272432
# Still in queue at :
# 2022-12-09 16:16:24.731712
# Still in queue at :
# 2022-12-09 16:16:28.268997
# Still in queue at :
# 2022-12-09 16:16:31.713347
# Still in queue at :
# 2022-12-09 16:16:35.160856
# Still in queue at :
# 2022-12-09 16:16:38.604197
# Still in queue at :
# 2022-12-09 16:16:42.001990
# Still in queue at :
# 2022-12-09 16:16:45.454135
# Still in queue at :
# 2022-12-09 16:16:48.886345
# Still in queue at :
# 2022-12-09 16:16:52.321027
# Still in queue at :
# 2022-12-09 16:16:55.753718
# Still in queue at :
# 2022-12-09 16:16:59.214570
# Still in queue at :
# 2022-12-09 16:17:02.652295
# Still in queue at :
# 2022-12-09 16:17:06.136989
# Still in queue at :
# 2022-12-09 16:17:09.636476
# Still in queue at :
# 2022-12-09 16:17:13.128727
# Still in queue at :
# 2022-12-09 16:17:16.624338
# Still in queue at :
# 2022-12-09 16:17:20.122032
# Still in queue at :
# 2022-12-09 16:17:23.675061
# Still in queue at :
# 2022-12-09 16:17:27.196603
# Still in queue at :
# 2022-12-09 16:17:30.725117
# Still in queue at :
# 2022-12-09 16:17:34.196739
# Still in queue at :
# 2022-12-09 16:17:37.695708
# Still in queue at :
# 2022-12-09 16:17:41.283166
# Still in queue at :
# 2022-12-09 16:17:44.821825
# Still in queue at :
# 2022-12-09 16:17:48.417108
# Still in queue at :
# 2022-12-09 16:17:51.967846
# Still in queue at :
# 2022-12-09 16:17:55.508764
# Still in queue at :
# 2022-12-09 16:17:59.081944
# Still in queue at :
# 2022-12-09 16:18:02.623224
# Still in queue at :
# 2022-12-09 16:18:06.214527
# Still in queue at :
# 2022-12-09 16:18:09.797515
# Still in queue at :
# 2022-12-09 16:18:13.379487
# Still in queue at :
# 2022-12-09 16:18:16.915988
# Still in queue at :
# 2022-12-09 16:18:20.455596
# Still in queue at :
# 2022-12-09 16:18:24.041648
# Still in queue at :
# 2022-12-09 16:18:27.528591
# Still in queue at :
# 2022-12-09 16:18:30.985643
# Still in queue at :
# 2022-12-09 16:18:34.425098
# Still in queue at :
# 2022-12-09 16:18:37.832033
# Still in queue at :
# 2022-12-09 16:18:41.307210
# Still in queue at :
# 2022-12-09 16:18:44.804763
# Still in queue at :
# 2022-12-09 16:18:48.278361
# Still in queue at :
# 2022-12-09 16:18:51.738608
# Still in queue at :
# 2022-12-09 16:18:55.209004
# Still in queue at :
# 2022-12-09 16:18:58.613828
# Still in queue at :
# 2022-12-09 16:19:02.058636
# Still in queue at :
# 2022-12-09 16:19:05.483093
# Still in queue at :
# 2022-12-09 16:19:08.895645
# Still in queue at :
# 2022-12-09 16:19:12.318662
# Still in queue at :
# 2022-12-09 16:19:15.786457
# Still in queue at :
# 2022-12-09 16:19:19.198260
# Still in queue at :
# 2022-12-09 16:19:22.597212
# Still in queue at :
# 2022-12-09 16:19:26.092606
# Still in queue at :
# 2022-12-09 16:19:29.619914
# Still in queue at :
# 2022-12-09 16:19:33.097942
# Still in queue at :
# 2022-12-09 16:19:36.573055
# Still in queue at :
# 2022-12-09 16:19:40.058121
# Still in queue at :
# 2022-12-09 16:19:43.548138
# Still in queue at :
# 2022-12-09 16:19:47.051982
# Still in queue at :
# 2022-12-09 16:19:50.618283
# Still in queue at :
# 2022-12-09 16:19:54.116175
# Still in queue at :
# 2022-12-09 16:19:57.584914
# Still in queue at :
# 2022-12-09 16:20:01.089339
# Still in queue at :
# 2022-12-09 16:20:04.544973
# Still in queue at :
# 2022-12-09 16:20:08.069598
# Still in queue at :
# 2022-12-09 16:20:11.553016
# Still in queue at :
# 2022-12-09 16:20:15.066503
# Still in queue at :
# 2022-12-09 16:20:18.545883
# Still in queue at :
# 2022-12-09 16:20:22.007497
# Still in queue at :
# 2022-12-09 16:20:25.483014
# Still in queue at :
# 2022-12-09 16:20:28.924174
# Still in queue at :
# 2022-12-09 16:20:32.390609
# Still in queue at :
# 2022-12-09 16:20:35.842270
# Still in queue at :
# 2022-12-09 16:20:39.294600
# Still in queue at :
# 2022-12-09 16:20:42.671358
# Still in queue at :
# 2022-12-09 16:20:46.125856
# Still in queue at :
# 2022-12-09 16:20:49.643009
# Still in queue at :
# 2022-12-09 16:20:53.192929
# Still in queue at :
# 2022-12-09 16:20:56.682358
# Still in queue at :
# 2022-12-09 16:21:00.387049
# Still in queue at :
# 2022-12-09 16:21:03.896097
# Still in queue at :
# 2022-12-09 16:21:07.357590
# Still in queue at :
# 2022-12-09 16:21:10.818883
# Still in queue at :
# 2022-12-09 16:21:14.323612
# Still in queue at :
# 2022-12-09 16:21:17.790326
# Still in queue at :
# 2022-12-09 16:21:21.268040
# Still in queue at :
# 2022-12-09 16:21:24.721320
# Still in queue at :
# 2022-12-09 16:21:28.157659
# Still in queue at :
# 2022-12-09 16:21:31.775134
# Still in queue at :
# 2022-12-09 16:21:35.490008
# Still in queue at :
# 2022-12-09 16:21:38.974549
# Still in queue at :
# 2022-12-09 16:21:42.447569
# Still in queue at :
# 2022-12-09 16:21:45.822920
# Still in queue at :
# 2022-12-09 16:21:49.303235
# Still in queue at :
# 2022-12-09 16:21:52.787360
# Still in queue at :
# 2022-12-09 16:21:56.267243

# %% [markdown]
# ### LOAD AND SAVE

# %%
ds = xr.Dataset()
if len(add)==1:
    ds = gu.core.open_frompp(pp,ppname,out,local,time,add[0])
else:
    for a in add:
        ds[a]=gu.core.open_frompp(pp,ppname,out,local,time,a)[a]

# %%
ds

# %%
with ProgressBar():
    ds.to_zarr(outpath,mode='a')
