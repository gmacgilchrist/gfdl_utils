# %%
# %load_ext autoreload
# %autoreload 2

# %%
import xarray as xr
import gfdl_utils as gu
from dask.diagnostics import ProgressBar
import os
import datetime

# %% [markdown]
# ## Save zarr stores
# Chug certain variables into a zarr store in `/work` for later use.
#
# Notebook is separated into four sections that should be considered quasi-independent:
# - **SEARCH**
#     - Various functions to find specific files or variables
#     - Most are dependent only on the pp directory
# - **SPECIFY**
#     - Give specifics of file(s) to be loaded and saved
#         - `ppname` (subfolder of `pp`)
#         - `out` (averaging of output: `av` or `ts`)
#         - `time` (timespan to be used, usually `*` for all time)
#         - `add` (name of variable (when `out==ts`) or `*` for `out==av`)
#             - `add` can be a list of severable variables, so long as they are all present in `ppname`
#     - Define filename for zarr store and check if it exists
#         - filename : ppname.out.zarr
# - **DMGET**
#     - Retrieve specified file(s) from tape
# - **LOAD AND SAVE**
#     - Load files into `ds` (loop through variables if several specified in `add`)
#     - Save to zarr store, appending to store if it already exists

# %%
config_id = 'ESM4_historical_D1'
pp = '/archive/oar.gfdl.cmip6/ESM4/DECK/'+config_id+'/gfdl.ncrc4-intel16-prod-openmp/pp'
# pp = '/archive/Raphael.Dussin/FMS2019.01.03_devgfdl_20210706/CM4_piControl_c192_OM4p125_v7/gfdl.ncrc4-intel18-prod-openmp/pp'

outdir = '/work/gam/zarr/'+config_id+'/'

# %% [markdown]
# ### SEARCH

# %% [markdown]
# #### List pp names

# %%
gu.core.get_ppnames(pp)
# Out:
# ['.dec',
#  '.checkpoint',
#  'ocean_daily_cmip',
#  'ocean_daily_gfdl',
#  'ocean_daily_1x1deg',
#  'ocean_monthly',
#  'ocean_monthly_1x1deg',
#  'ocean_month_rho2',
#  'ocean_month_rho2_1x1deg',
#  'ocean_monthly_z',
#  'ocean_monthly_z_1x1deg',
#  'ocean_annual',
#  'ocean_annual_1x1deg',
#  'ocean_annual_rho2',
#  'ocean_annual_rho2_1x1deg',
#  'ocean_annual_z',
#  'ocean_annual_z_1x1deg',
#  'ocean_scalar_monthly',
#  'ocean_scalar_annual',
#  'ocean_Barents_opening',
#  'ocean_Bering_Strait',
#  'ocean_Davis_Strait',
#  'ocean_Windward_Passage',
#  'ocean_Denmark_Strait',
#  'ocean_Drake_Passage',
#  'ocean_English_Channel',
#  'ocean_Faroe_Scotland',
#  'ocean_Florida_Bahamas',
#  'ocean_Fram_Strait',
#  'ocean_Iceland_Faroe_V',
#  'ocean_Iceland_Faroe_U',
#  'ocean_Indonesian_Throughflow',
#  'ocean_Mozambique_Channel',
#  'ocean_Pacific_undercurrent',
#  'ocean_Taiwan_Luzon',
#  'ocean_Agulhas_section',
#  'ocean_Gibraltar_Strait',
#  'ocean_Iceland_Norway',
#  'ocean_month_refined',
#  'ocean_month_z_refined',
#  'ocean_month_rho2_refined',
#  'atmos_cmip',
#  'atmos',
#  'atmos_level_cmip',
#  'atmos_level',
#  'atmos_plev39_cmip',
#  'atmos_plev39_6hr',
#  'atmos_plev39_cmip_daily',
#  'atmos_month_aer',
#  'atmos_diurnal_cmip',
#  'atmos_diurnal',
#  'atmos_scalar',
#  'tracer_level',
#  'aerosol_cmip',
#  'land',
#  'land_cubic',
#  'land_instant_cubic',
#  'land_cmip',
#  'land_dust',
#  'river',
#  'river_cubic',
#  'river_instant_cubic',
#  'LUmip_month_psl',
#  'LUmip_month_crp',
#  'LUmip_month_pst',
#  'LUmip_refined',
#  'LUmip_year_psl',
#  'LUmip_year_crp',
#  'LUmip_year_pst',
#  'land_by_species',
#  'fire',
#  'aerosol_hourly_cmip',
#  'atmos_co2_level',
#  'ocean_cobalt_sfc',
#  'ocean_cobalt_btm',
#  'ocean_cobalt_fdet_100',
#  'ocean_cobalt_tracers_int',
#  'ocean_cobalt_fluxes_int',
#  'ocean_cobalt_tracers_year_z',
#  'ocean_cobalt_omip_daily',
#  'ocean_cobalt_omip_sfc',
#  'ocean_cobalt_omip_2d',
#  'ocean_cobalt_omip_tracers_month_z',
#  'ocean_cobalt_omip_tracers_year_z',
#  'ocean_cobalt_omip_rates_year_z',
#  'ocean_cobalt_omip_daily_1x1deg',
#  'ocean_cobalt_omip_sfc_1x1deg',
#  'ocean_cobalt_omip_2d_1x1deg',
#  'ocean_cobalt_omip_tracers_month_z_1x1deg',
#  'ocean_cobalt_omip_tracers_year_z_1x1deg',
#  'ocean_cobalt_omip_rates_year_z_1x1deg',
#  'ocean_inert_month',
#  'ocean_inert_month_1x1deg',
#  'ocean_inert_z',
#  'ocean_inert_z_1x1deg',
#  'atmos_cmip_Plev8',
#  '_DELETE',
#  'ice',
#  'ice_1x1deg',
#  'LUmip_refined_year',
#  'DO_NOT_USE']

# %% [markdown]
# #### List all available variables

# %%
gu.core.get_allvars(pp)
# Out:
# {'ocean_daily': ['tos_max',
#   'omldamax',
#   'sos',
#   'tos_min',
#   'ssu',
#   'tos',
#   'ssv',
#   'ustar',
#   'zos_max',
#   'zos_min',
#   'zos',
#   'zossq'],
#  'ocean_daily_d2': ['zos_min',
#   'mlotst',
#   'zos_max',
#   'omldamax',
#   'tos_max',
#   'sos',
#   'tos_min',
#   'ssu',
#   'tos',
#   'ssv',
#   'zos',
#   'zossq'],
#  'ocean_daily_1x1deg': ['tos_min',
#   'omldamax',
#   'sos',
#   'tos',
#   'tos_max',
#   'ustar',
#   'zos_max',
#   'zos_min',
#   'zos',
#   'zossq'],
#  'ocean_monthly': ['hfsnthermds',
#   'col_height',
#   'mass_wt',
#   'col_mass',
#   'MLD_003_max',
#   'ePBL_h_ML',
#   'MLD_003_min',
#   'evs',
#   'MLD_003',
#   'ficeberg',
#   'MLD_EN1_max',
#   'friver',
#   'MLD_EN1_min',
#   'fsitherm',
#   'hfsso',
#   'heat_content_cond',
#   'hfrunoffds',
#   'heat_content_fprec',
#   'heat_content_massin',
#   'hf_rvxu_2d',
#   'heat_content_massout',
#   'hf_rvxv_2d',
#   'heat_content_surfwater',
#   'hfsifrazil',
#   'heat_content_vprec',
#   'MLD_EN1',
#   'Heat_PmE',
#   'MLD_EN2',
#   'hf_CAu_2d',
#   'MLD_EN3',
#   'hf_CAv_2d',
#   'hf_u_BT_accel_2d',
#   'hf_diffu_2d',
#   'hf_v_BT_accel_2d',
#   'hf_diffv_2d',
#   'net_massin',
#   'hfds',
#   'intz_CAu_2d',
#   'hf_dudt_2d',
#   'intz_CAv_2d',
#   'hf_du_dt_visc_2d',
#   'intz_gKEv_2d',
#   'hf_dvdt_2d',
#   'intz_PFu_2d',
#   'hf_dv_dt_visc_2d',
#   'net_massout',
#   'hfevapds',
#   'intz_PFv_2d',
#   'hf_gKEu_2d',
#   'intz_rvxu_2d',
#   'hf_gKEv_2d',
#   'intz_rvxv_2d',
#   'hfibthermds',
#   'nonpenSW',
#   'hflso',
#   'opottempmint',
#   'hf_PFu_2d',
#   'pbo',
#   'hf_PFv_2d',
#   'prlq',
#   'hfrainds',
#   'intz_diffu_2d',
#   'intz_u_BT_accel_2d',
#   'intz_diffv_2d',
#   'intz_v_BT_accel_2d',
#   'intz_gKEu_2d',
#   'LwLatSens',
#   'net_heat_coupler',
#   'prsn',
#   'rlntds',
#   'rsdo',
#   'rsntds',
#   'S_adx_2d',
#   'S_ady_2d',
#   'salt_flux_added',
#   'sfdsi',
#   'sob',
#   'somint',
#   'sos',
#   'T_adx_2d',
#   'T_ady_2d',
#   'tauuo',
#   'tauvo',
#   'taux_bot',
#   'taux',
#   'tauy_bot',
#   'tauy',
#   'tob',
#   'tos',
#   'ubt_dt',
#   'umo_2d',
#   'ustar',
#   'vbt_dt',
#   'vmo_2d',
#   'vprec',
#   'wfo',
#   'zos'],
#  'ocean_monthly_1x1deg': ['rsdo',
#   'col_height',
#   'rsntds',
#   'col_mass',
#   'sfdsi',
#   'ePBL_h_ML',
#   'sob',
#   'evs',
#   'somint',
#   'ficeberg',
#   'sos',
#   'friver',
#   'tob',
#   'fsitherm',
#   'MLD_EN2',
#   'heat_content_cond',
#   'net_massout',
#   'heat_content_fprec',
#   'MLD_EN1_max',
#   'heat_content_massin',
#   'MLD_EN1_min',
#   'heat_content_massout',
#   'heat_content_surfwater',
#   'nonpenSW',
#   'heat_content_vprec',
#   'tos',
#   'Heat_PmE',
#   'ustar',
#   'hfds',
#   'vprec',
#   'hfevapds',
#   'opottempmint',
#   'hfibthermds',
#   'wfo',
#   'hflso',
#   'zos',
#   'hfrainds',
#   'hfrunoffds',
#   'hfsifrazil',
#   'pbo',
#   'hfsnthermds',
#   'hfsso',
#   'LwLatSens',
#   'mass_wt',
#   'prlq',
#   'MLD_003_max',
#   'prsn',
#   'MLD_003_min',
#   'MLD_003',
#   'MLD_EN1',
#   'MLD_EN3',
#   'rlntds',
#   'net_heat_coupler',
#   'net_massin',
#   'salt_flux_added'],
#  'ocean_month_z': ['so',
#   'rhopot0',
#   'rsdo',
#   'rsdoabsorb',
#   'thetao',
#   'thkcello',
#   'umo',
#   'uo',
#   'vmo',
#   'volcello',
#   'vo'],
#  'ocean_month_rho2': ['umo', 'thkcello', 'uhml', 'volcello', 'vhml', 'vmo'],
#  'ocean_monthly_d2': ['ePBL_h_ML',
#   'wfo',
#   'MLD_003_max',
#   'MLD_003_min',
#   'MLD_EN1_max',
#   'MLD_003',
#   'MLD_EN1_min',
#   'MLD_EN1',
#   'MLD_EN2',
#   'MLD_EN3',
#   'S_adx_2d',
#   'S_ady_2d',
#   'sos',
#   'T_adx_2d',
#   'T_ady_2d',
#   'tos'],
#  'ocean_monthly_z_d2': ['S_advection_xy',
#   'boundary_forcing_heat_tendency',
#   'internal_heat_heat_tendency',
#   'boundary_forcing_salt_tendency',
#   'osaltpmdiff',
#   'frazil_heat_tendency',
#   'opottemppmdiff',
#   'thkcello',
#   'obvfsq',
#   'uo',
#   'opottempdiff',
#   'Sh_tendency_vert_remap',
#   'umo',
#   'opottemptend',
#   'vhml',
#   'osaltdiff',
#   'vmo',
#   'volcello',
#   'osalttend',
#   'so',
#   'rsdo',
#   'thetao',
#   'T_advection_xy',
#   'vo',
#   'Th_tendency_vert_remap'],
#  'ocean_month_z_d2_snap': ['so', 'thetao', 'thkcello', 'volcello'],
#  'ocean_month_rho2_d2': ['vmo', 'thkcello', 'volcello', 'vhml'],
#  'ocean_monthly_z_d2_1x1deg': ['obvfsq',
#   'boundary_forcing_heat_tendency',
#   'opottempdiff',
#   'boundary_forcing_salt_tendency',
#   'so',
#   'frazil_heat_tendency',
#   'osaltdiff',
#   'internal_heat_heat_tendency',
#   'T_advection_xy',
#   'opottemppmdiff',
#   'opottemptend',
#   'osaltpmdiff',
#   'osalttend',
#   'rsdo',
#   'thetao',
#   'S_advection_xy',
#   'Sh_tendency_vert_remap',
#   'thkcello',
#   'Th_tendency_vert_remap',
#   'volcello'],
#  'ocean_annual_rho2_d2': ['umo',
#   'thkcello',
#   'uhml',
#   'volcello',
#   'vhml',
#   'vmo'],
#  'ocean_annual_rho2': ['vmo', 'thkcello', 'volcello', 'uhml', 'vhml', 'umo'],
#  'ocean_annual_rho2_d2_1x1deg': ['volcello', 'thkcello'],
#  'ocean_annual_rho2_1x1deg': ['volcello', 'thkcello'],
#  'ocean_month_rho2_1x1deg': ['volcello', 'thkcello'],
#  'ocean_annual': ['LwLatSens',
#   'evs',
#   'heat_content_cond',
#   'ficeberg',
#   'net_massin',
#   'friver',
#   'heat_content_fprec',
#   'fsitherm',
#   'thkcello',
#   'thetao',
#   'TKE_itidal',
#   'heat_content_massin',
#   'TKE_tidal',
#   'heat_content_massout',
#   'ustar',
#   'heat_content_surfwater',
#   'heat_content_vprec',
#   'Heat_PmE',
#   'nonpenSW',
#   'hfds',
#   'hfevapds',
#   'hfibthermds',
#   'prsn',
#   'hflso',
#   'hfrainds',
#   'hfrunoffds',
#   'hfsifrazil',
#   'hfsnthermds',
#   'prlq',
#   'hfsso',
#   'net_heat_coupler',
#   'net_massout',
#   'rlntds',
#   'rsdo',
#   'rsntds',
#   'sfdsi',
#   'so',
#   'salt_flux_added',
#   'tauuo',
#   'tauvo',
#   'vprec',
#   'wfo'],
#  'ocean_annual_z': ['umo',
#   'obvfsq',
#   'volcello',
#   'so',
#   'thetao_xyave',
#   'so_xyave',
#   'vmo',
#   'thetao'],
#  'ocean_annual_z_1x1deg': ['volcello', 'obvfsq', 'so', 'thetao'],
#  'ocean_annual_z_d2': ['Kd_interface',
#   'agessc',
#   'boundary_forcing_heat_tendency',
#   'uh',
#   'boundary_forcing_salt_tendency',
#   'Kd_itides',
#   'difmxybo',
#   'Kd_shear',
#   'difvho',
#   'obvfsq',
#   'difvso',
#   'uo',
#   'frazil_heat_tendency',
#   'umo',
#   'internal_heat_heat_tendency',
#   'opottempdiff',
#   'Kd_BBL',
#   'opottemptend',
#   'Kd_ePBL',
#   'vmo',
#   'osaltdiff',
#   'osaltpmdiff',
#   'osalttend',
#   'rsdoabsorb',
#   'S_adx',
#   'S_advection_xy',
#   'S_ady',
#   'so',
#   'vhml',
#   'Sh_tendency_vert_remap',
#   'T_adx',
#   'T_advection_xy',
#   'T_ady',
#   'thetao',
#   'uhml',
#   'vh',
#   'Th_tendency_vert_remap',
#   'volcello',
#   'vo'],
#  'ocean_annual_z_d2_1x1deg': ['opottemptend',
#   'agessc',
#   'boundary_forcing_salt_tendency',
#   'boundary_forcing_heat_tendency',
#   'osaltdiff',
#   'difmxybo',
#   'osaltpmdiff',
#   'difvho',
#   'osalttend',
#   'difvso',
#   'frazil_heat_tendency',
#   'internal_heat_heat_tendency',
#   'rsdoabsorb',
#   'Kd_BBL',
#   'S_advection_xy',
#   'Kd_ePBL',
#   'Kd_interface',
#   'so',
#   'Kd_itides',
#   'T_advection_xy',
#   'Kd_shear',
#   'thetao',
#   'obvfsq',
#   'opottempdiff',
#   'volcello',
#   'Sh_tendency_vert_remap',
#   'Th_tendency_vert_remap'],
#  'ocean_monthly_z3': ['volcello', 'so', 'thetao_xyave', 'so_xyave', 'thetao'],
#  'ocean_annual_z3': ['thetao', 'so', 'volcello', 'so_xyave', 'thetao_xyave'],
#  'ocean_scalar_monthly': ['tosga',
#   'ave_evs',
#   'volo',
#   'ave_hfds',
#   'ave_hflso',
#   'ave_hfsso',
#   'ave_rlntds',
#   'ave_rsntds',
#   'masso',
#   'ave_wfo',
#   'ssh_ga',
#   'LwLatSens_ga',
#   'soga',
#   'net_heat_coupler_ga',
#   'precip_ga',
#   'sosga',
#   'thetaoga'],
#  'ocean_scalar_annual': ['ave_hfds',
#   'ave_evs',
#   'volo',
#   'ave_hflso',
#   'ave_hfsso',
#   'ave_rlntds',
#   'ave_rsntds',
#   'ave_wfo',
#   'LwLatSens_ga',
#   'masso',
#   'thetaoga',
#   'net_heat_coupler_ga',
#   'precip_ga',
#   'soga',
#   'sosga',
#   'ssh_ga',
#   'tosga'],
#  'ice': ['LH',
#   'ALB',
#   'sivol',
#   'BHEAT',
#   'SN2IC',
#   'BMELT',
#   'SNOWFL',
#   'BSNK',
#   'siv',
#   'CALVING_HFLX',
#   'SSH',
#   'CALVING',
#   'HS',
#   'CN',
#   'SSS',
#   'E2MELT',
#   'STRENGTH_hf',
#   'EVAP',
#   'SST',
#   'EXT_MAX',
#   'SW',
#   'EXT_MIN',
#   'LSRC',
#   'EXT',
#   'T1',
#   'FA_X',
#   'T2',
#   'FA_Y',
#   'T3',
#   'FI_X',
#   'XPRT',
#   'FI_Y',
#   'FRAZIL',
#   'LSNK',
#   'HI',
#   'MIB',
#   'HP',
#   'LW',
#   'IX_TRANS',
#   'IY_TRANS',
#   'RUNOFF',
#   'RAIN',
#   'SALTF',
#   'simass',
#   'SH',
#   'siconc',
#   'sisnconc',
#   'sisnmass',
#   'sisnthick',
#   'sispeed',
#   'sitemptop',
#   'sithick',
#   'sitimefrac',
#   'siu',
#   'T4',
#   'TMELT',
#   'TSN',
#   'UO',
#   'VO'],
#  'ice_1x1deg': ['FRAZIL',
#   'ALB',
#   'SNOWFL',
#   'BHEAT',
#   'SSH',
#   'BMELT',
#   'HI',
#   'BSNK',
#   'SST',
#   'CALVING_HFLX',
#   'SSS',
#   'CALVING',
#   'HP',
#   'CN',
#   'STRENGTH_hf',
#   'E2MELT',
#   'HS',
#   'EVAP',
#   'SW',
#   'EXT_MAX',
#   'T1',
#   'EXT_MIN',
#   'LH',
#   'EXT',
#   'T2',
#   'LSNK',
#   'LSRC',
#   'LW',
#   'MIB',
#   'RAIN',
#   'RUNOFF',
#   'SALTF',
#   'SH',
#   'siconc',
#   'T3',
#   'simass',
#   'sisnconc',
#   'sisnmass',
#   'sisnthick',
#   'sispeed',
#   'sitemptop',
#   'sithick',
#   'sitimefrac',
#   'sivol',
#   'SN2IC',
#   'T4',
#   'TMELT',
#   'TSN',
#   'XPRT'],
#  'ice_daily': ['sisnmass',
#   'BHEAT',
#   'sisnconc',
#   'BMELT',
#   'sisnthick',
#   'BSNK',
#   'siv',
#   'CN',
#   'SSH',
#   'LH',
#   'SSS',
#   'LSNK',
#   'SST',
#   'LSRC',
#   'SW',
#   'LW',
#   'TMELT',
#   'SH',
#   'XPRT',
#   'siconc',
#   'simass',
#   'sitemptop',
#   'sithick',
#   'siu'],
#  'ice_daily_extra': ['RAIN',
#   'ALB',
#   'FRAZIL',
#   'E2MELT',
#   'IX_TRANS',
#   'EVAP',
#   'IY_TRANS',
#   'FA_X',
#   'FA_Y',
#   'SALTF',
#   'FI_X',
#   'RUNOFF',
#   'FI_Y',
#   'sispeed',
#   'SN2IC',
#   'SNOWFL',
#   'STRENGTH_hf',
#   'T1',
#   'T2',
#   'UO',
#   'VO',
#   'T3',
#   'T4',
#   'TSN'],
#  'ocean_month_z_d2_refined': ['msftyzsmpa', 'mfo', 'msftyyz', 'wmo'],
#  'ocean_month_rho2_d2_refined': ['msftyrho'],
#  'ocean_month_rho2_refined': ['msftyrho'],
#  'atmos': ['prec_ls', 'olr', 'precip', 'prec_conv'],
#  'atmos_month_aer': ['aer_c',
#   'aer_ab_c_vs',
#   'aer_ab_vs',
#   'sulfate',
#   'aer_ex_c_vs',
#   'aer_ex_vs',
#   'b5_exopd_vl_c',
#   'blk_crb_col',
#   'blk_crb_ex_c_vs',
#   'temp',
#   'blk_crb',
#   'lg_dust',
#   'bnd6_exopd_vl_c',
#   'lg_dust_col',
#   'lg_dst_ex_c_vs',
#   'nir_exopd_vl_c',
#   'org_crb_col',
#   'org_crb_ex_c_vs',
#   'org_crb',
#   'ps',
#   'salt_col',
#   'salt_ex_c_vs',
#   'salt',
#   'sm_dst_ex_c_vs',
#   'sm_dust_col',
#   'sm_dust',
#   'sphum',
#   'sulfate_col',
#   'sulfate_ex_c_vs',
#   'vis_exopd_vl_c'],
#  'atmos_diurnal': ['t_ref',
#   'evap',
#   'z_Ri_025',
#   'prec_conv',
#   'precip',
#   'shflx'],
#  'atmos_scalar': ['co2mass',
#   'cfc113global',
#   'ch4global',
#   'cfc11global',
#   'hcfc22global',
#   'cfc12global',
#   'n2oglobal',
#   'rrvch4',
#   'rrvco2',
#   'rrvf113',
#   'rrvf11',
#   'rrvf12',
#   'rrvf22',
#   'rrvn2o',
#   'solar_constant'],
#  'land': ['levapg_soil',
#   'albedo_dif',
#   'levaps',
#   'albedo_dir',
#   'meltg_glac',
#   'an_cl',
#   'melt',
#   'an_op',
#   'melts',
#   'area_ntrl',
#   'nep',
#   'asoil',
#   'soil_T',
#   'bl',
#   'npp',
#   'blv',
#   'ssc',
#   'br',
#   'past_harv_pool',
#   'bsw',
#   'past_harv_rate',
#   'bwood',
#   'LAI',
#   'cleared_harv_pool',
#   'lake_dz',
#   'cleared_harv_rate',
#   'lake_T',
#   'crop_harv_pool',
#   'lake_K_z',
#   'crop_harv_rate',
#   'lake_wl',
#   'csmoke_rate',
#   'precip',
#   'evap_glac',
#   'qca',
#   'evap_lake',
#   'qco2_phot',
#   'evap_land',
#   'resg',
#   'evap_soil',
#   'resp',
#   'fevapg',
#   'LWS',
#   'fevapg_soil',
#   'rsoil_fast',
#   'fevaps',
#   'lake_ws',
#   'fevaps_soil',
#   'rsoil',
#   'fevapv',
#   'levapg',
#   'fevapv_soil',
#   'runf',
#   'flw',
#   'SAI',
#   'fprec_l',
#   'sens',
#   'frunf',
#   'snow_glac',
#   'fsc',
#   'snow_lake',
#   'fsw',
#   'snow',
#   'FWS',
#   'snow_soil',
#   'FWSv',
#   'soil_fgw',
#   'glac_T',
#   'soil_fsat',
#   'gpp',
#   'soil_ice',
#   'grnd_flux',
#   'soil_liq',
#   'hevap',
#   'soil_psi',
#   'hprec',
#   'soil_psi_n',
#   'hrunf',
#   'levaps_soil',
#   'soil_rbf',
#   'levapv',
#   'LWSv',
#   'levapv_soil',
#   'soil_rie',
#   'lwdn',
#   'vegn_height',
#   'Tca',
#   'soil_rnu',
#   'soil_rsn',
#   'soil_uptk',
#   'soil_uptk_ntrl',
#   'soil_wt_4',
#   'soil_wtdep',
#   'species',
#   'swdn_dif',
#   'swdn_dir',
#   'swup_dif',
#   'swup_dir',
#   'Tgrnd',
#   'theta',
#   'Trad',
#   'transp',
#   't_ref',
#   'tsoil_av',
#   'vegn_rden',
#   'vegn_rzeta',
#   'vegn_sncrit',
#   'vegn_T',
#   'water_lake',
#   'water_soil',
#   'wood_fast_harv_pool',
#   'wood_fast_harv_rate',
#   'wood_med_harv_pool',
#   'wood_med_harv_rate',
#   'wood_slow_harv_pool',
#   'wood_slow_harv_rate'],
#  'land_cubic': ['tile1', 'tile2', 'tile3', 'tile4', 'tile5', 'tile6'],
#  'land_instant_cubic': ['tile5', 'tile1', 'tile6', 'tile2', 'tile3', 'tile4'],
#  'land_cmip': [],
#  'land_dust': [],
#  'river': [],
#  'river_cubic': ['tile2', 'tile1', 'tile4', 'tile3', 'tile5', 'tile6'],
#  'river_instant_cubic': ['tile4', 'tile1', 'tile5', 'tile2', 'tile6', 'tile3'],
#  'atmos_cmip': ['ua_unmsk',
#   'albs',
#   'vas',
#   'hur',
#   'va_unmsk',
#   'hus',
#   'zg_unmsk',
#   'o3',
#   'ta',
#   'rsdt',
#   't_ref_max',
#   'rsds',
#   't_ref_min',
#   'ua',
#   'va',
#   'wap',
#   'zg',
#   'ccb',
#   'cct',
#   'ci',
#   'rsuscs',
#   'clivi',
#   'clt',
#   'rsus',
#   'clwvi',
#   'rsutcs',
#   'evspsbl',
#   'hfls',
#   'hfss',
#   'hurs',
#   'rsut',
#   'hur_unmsk',
#   'huss',
#   'tauu',
#   'hus_unmsk',
#   'ta_unmsk',
#   'o3_unmsk',
#   'prc',
#   'pr',
#   'prsn',
#   'prw',
#   'psl',
#   'ps',
#   'tauv',
#   'rldscs',
#   'rlds',
#   'rlus',
#   'rlutcs',
#   'rlut',
#   'ts',
#   'rsdscs',
#   'rtmt',
#   'sci',
#   'uas',
#   'sfcWind',
#   'tas',
#   'wap_unmsk'],
#  'ocean_Barents_opening': ['uo', 'so', 'thetao', 'volcello', 'umo'],
#  'ocean_Bering_Strait': ['volcello', 'so', 'vo', 'thetao', 'vmo'],
#  'ocean_Davis_Strait': ['so', 'thetao', 'volcello', 'vmo', 'vo'],
#  'ocean_Windward_Passage': ['volcello', 'so', 'thetao', 'vo', 'vmo'],
#  'ocean_Denmark_Strait': ['so', 'vo', 'thetao', 'vmo', 'volcello'],
#  'ocean_Drake_Passage': ['uo', 'so', 'volcello', 'thetao', 'umo'],
#  'ocean_English_Channel': ['uo', 'so', 'thetao', 'volcello', 'umo'],
#  'ocean_Faroe_Scotland': ['volcello', 'so', 'thetao', 'umo', 'uo'],
#  'ocean_Florida_Bahamas': ['volcello', 'so', 'thetao', 'vo', 'vmo'],
#  'ocean_Fram_Strait': ['so', 'thetao', 'volcello', 'vmo', 'vo'],
#  'ocean_Iceland_Faroe_V': ['volcello', 'so', 'thetao', 'vo', 'vmo'],
#  'ocean_Iceland_Faroe_U': ['uo', 'so', 'thetao', 'volcello', 'umo'],
#  'ocean_Indonesian_Throughflow': ['thetao', 'so', 'vmo', 'volcello', 'vo'],
#  'ocean_Mozambique_Channel': ['vo', 'so', 'thetao', 'volcello', 'vmo'],
#  'ocean_Pacific_undercurrent': ['uo', 'so', 'umo', 'thetao', 'volcello'],
#  'ocean_Taiwan_Luzon': ['so', 'thetao', 'uo', 'umo', 'volcello'],
#  'ocean_Agulhas_section': ['uo', 'so', 'thetao', 'volcello', 'umo'],
#  'ocean_Gibraltar_Strait': ['uo', 'so', 'thetao', 'volcello', 'umo'],
#  'ocean_Iceland_Norway': ['so', 'vo', 'thetao', 'vmo', 'volcello'],
#  'bergs_month': ['virtual_area',
#   'accum_calving',
#   'calving_hflx_in',
#   'melt_conv',
#   'mass',
#   'melt_buoy',
#   'melt_eros',
#   'melt',
#   'real_calving',
#   'stored_ice',
#   'unused_calving'],
#  'ocean_monthly_refined': ['hfbasin', 'hfx', 'hfy'],
#  'ocean_month_z_refined': ['mfo', 'msftyyz', 'wmo'],
#  'atmos_tracer': ['ssalt4',
#   'bcphil',
#   'ssalt5',
#   'bcphob',
#   'temp',
#   'dust1',
#   'dust2',
#   'dust3',
#   'dust4',
#   'dust5',
#   'omphil',
#   'omphob',
#   'ps',
#   'radon',
#   'SOA',
#   'sphum',
#   'ssalt1',
#   'ssalt2',
#   'ssalt3'],
#  'ocean_annual_rho2l35': ['umo', 'vmo']}

# %% [markdown]
# #### Find ppname for specific variable

# %%
gu.core.find_variable(pp,'o2')
# Out:
# ['ocean_cobalt_omip_tracers_month_z',
#  'ocean_cobalt_omip_tracers_year_z',
#  'ocean_cobalt_omip_tracers_month_z_1x1deg',
#  'ocean_cobalt_omip_tracers_year_z_1x1deg']

# %% [markdown]
# #### Display variables in specific ppname

# %%
gu.core.get_varnames(pp,'ocean_cobalt_omip_tracers_month_z_1x1deg')
# Out:
# ['chl',
#  'co3',
#  'co3satarag',
#  'co3satcalc',
#  'dfe',
#  'dissic',
#  'dissoc',
#  'expc',
#  'graz',
#  'nh4',
#  'no3',
#  'o2',
#  'o2sat',
#  'ph',
#  'phyc',
#  'phydiat',
#  'phydiaz',
#  'phymisc',
#  'phypico',
#  'po4',
#  'pon',
#  'pp',
#  'si',
#  'talk',
#  'volcello',
#  'zmeso',
#  'zmicro',
#  'zooc',
#  'dissoc_orig']

# %% [markdown]
# ### SPECIFY

# %%
ppname = 'ocean_cobalt_omip_tracers_month_z_1x1deg'
out = 'ts'
add = ['o2','o2sat'] # type : list; can specify multiple variables if same ppname
time = '*'

# %%
filename = '.'.join([ppname,out,'zarr'])

# %%
if os.path.exists(outdir):
    print("Directory exists : "+outdir)
else:
    print("Creating directory : "+outdir)
    os.mkdir(outdir)

outpath = outdir+filename
if os.path.exists(outpath):
    print("zarr store exists : "+outpath)
    print("Variables will be appended.")
else:
    print("zarr store will be created : "+outpath)
# Out:
# Directory exists : /work/gam/zarr/ESM4_historical_D1/
# zarr store will be created : /work/gam/zarr/ESM4_historical_D1/ocean_cobalt_omip_tracers_month_z_1x1deg.ts.zarr

# %% [markdown]
# ### DMGET

# %%
local = gu.core.get_local(pp,ppname,out)

# %%
if len(add)==1:
    path = gu.core.get_pathspp(pp,ppname,out,local,time,add[0])
    gu.core.issue_dmget(path)
else:
    for a in add:
        path = gu.core.get_pathspp(pp,ppname,out,local,time,a)
        gu.core.issue_dmget(path)

# %%
gu.core.query_dmget()
# Out:
# 0

# %%
# Snippet of code that will only complete when out of queue
count = 0
while gu.core.query_dmget()==1:
    count+=1
    if count%100==0:
        print("Still in queue at :")
        print(datetime.datetime.now())

# %% [markdown]
# ### LOAD AND SAVE

# %%
ds = xr.Dataset()
if len(add)==1:
    ds = gu.core.open_frompp(pp,ppname,out,local,time,add[0])
else:
    for a in add:
        ds[a]=gu.core.open_frompp(pp,ppname,out,local,time,a)[a]

# %%
ds

# %%
with ProgressBar():
    ds.to_zarr(outpath,mode='a')
